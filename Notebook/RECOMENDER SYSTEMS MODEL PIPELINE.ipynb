# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import KNNBaseline
from surprise.model_selection import GridSearchCV

# %%
from surprise.model_selection import train_test_split

# %%
df = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to C:\Users\choha/.surprise_data/ml-100k

# %%
trainset, testset = train_test_split(df, test_size=.25)

# %%
algo = SVD()

# %%
model = SVD()

# %%
testset
# Out:
# [('254', '50', 5.0),
#  ('825', '1028', 3.0),
#  ('932', '177', 4.0),
#  ('383', '464', 4.0),
#  ('155', '245', 2.0),
#  ('495', '4', 3.0),
#  ('640', '941', 5.0),
#  ('543', '443', 4.0),
#  ('326', '550', 5.0),
#  ('223', '1052', 1.0),
#  ('248', '153', 3.0),
#  ('239', '205', 3.0),
#  ('263', '168', 5.0),
#  ('305', '1512', 3.0),
#  ('1', '49', 3.0),
#  ('207', '144', 3.0),
#  ('498', '1404', 3.0),
#  ('592', '323', 1.0),
#  ('359', '181', 5.0),
#  ('164', '248', 4.0),
#  ('276', '325', 3.0),
#  ('92', '356', 3.0),
#  ('416', '997', 3.0),
#  ('806', '484', 4.0),
#  ('201', '511', 3.0),
#  ('756', '71', 3.0),
#  ('429', '45', 3.0),
#  ('535', '1098', 5.0),
#  ('835', '486', 4.0),
#  ('572', '1010', 2.0),
#  ('936', '251', 4.0),
#  ('639', '174', 4.0),
#  ('568', '606', 5.0),
#  ('834', '762', 4.0),
#  ('864', '143', 4.0),
#  ('823', '128', 2.0),
#  ('655', '288', 3.0),
#  ('552', '411', 3.0),
#  ('659', '654', 4.0),
#  ('158', '56', 5.0),
#  ('498', '12', 4.0),
#  ('870', '284', 2.0),
#  ('58', '684', 4.0),
#  ('466', '651', 3.0),
#  ('886', '15', 3.0),
#  ('561', '141', 2.0),
#  ('833', '577', 1.0),
#  ('336', '121', 4.0),
#  ('387', '593', 3.0),
#  ('639', '97', 1.0),
#  ('59', '68', 2.0),
#  ('263', '143', 5.0),
#  ('7', '652', 3.0),
#  ('11', '15', 5.0),
#  ('577', '403', 4.0),
#  ('545', '510', 3.0),
#  ('256', '387', 4.0),
#  ('333', '520', 4.0),
#  ('887', '1413', 4.0),
#  ('715', '90', 5.0),
#  ('716', '48', 5.0),
#  ('489', '300', 5.0),
#  ('246', '250', 4.0),
#  ('387', '100', 5.0),
#  ('385', '1012', 3.0),
#  ('543', '89', 4.0),
#  ('161', '215', 2.0),
#  ('94', '68', 4.0),
#  ('632', '7', 3.0),
#  ('440', '937', 5.0),
#  ('574', '319', 5.0),
#  ('56', '67', 2.0),
#  ('790', '217', 4.0),
#  ('889', '124', 4.0),
#  ('312', '654', 5.0),
#  ('193', '33', 3.0),
#  ('704', '222', 3.0),
#  ('622', '1216', 4.0),
#  ('311', '468', 4.0),
#  ('53', '257', 4.0),
#  ('7', '560', 3.0),
#  ('403', '237', 5.0),
#  ('347', '1012', 4.0),
#  ('588', '815', 4.0),
#  ('270', '596', 5.0),
#  ('164', '276', 3.0),
#  ('49', '258', 2.0),
#  ('399', '379', 3.0),
#  ('732', '332', 5.0),
#  ('411', '174', 4.0),
#  ('94', '418', 3.0),
#  ('276', '1073', 3.0),
#  ('318', '405', 2.0),
#  ('758', '186', 5.0),
#  ('478', '98', 5.0),
#  ('194', '153', 3.0),
#  ('293', '708', 3.0),
#  ('255', '222', 3.0),
#  ('145', '1210', 1.0),
#  ('942', '878', 4.0),
#  ('870', '699', 3.0),
#  ('409', '205', 3.0),
#  ('918', '135', 1.0),
#  ('250', '480', 5.0),
#  ('546', '895', 3.0),
#  ('363', '231', 1.0),
#  ('179', '353', 1.0),
#  ('103', '126', 5.0),
#  ('867', '51', 3.0),
#  ('561', '164', 2.0),
#  ('181', '1349', 1.0),
#  ('506', '749', 4.0),
#  ('234', '1456', 4.0),
#  ('497', '184', 3.0),
#  ('782', '1590', 3.0),
#  ('495', '143', 1.0),
#  ('902', '1016', 2.0),
#  ('883', '1171', 5.0),
#  ('558', '116', 5.0),
#  ('693', '604', 3.0),
#  ('640', '201', 4.0),
#  ('450', '76', 3.0),
#  ('634', '300', 3.0),
#  ('822', '95', 4.0),
#  ('239', '304', 1.0),
#  ('276', '653', 5.0),
#  ('916', '186', 3.0),
#  ('917', '121', 1.0),
#  ('406', '675', 4.0),
#  ('194', '4', 4.0),
#  ('894', '148', 3.0),
#  ('56', '172', 5.0),
#  ('230', '98', 5.0),
#  ('749', '139', 4.0),
#  ('758', '1025', 3.0),
#  ('816', '323', 4.0),
#  ('433', '59', 5.0),
#  ('293', '685', 3.0),
#  ('60', '660', 4.0),
#  ('805', '169', 4.0),
#  ('59', '1021', 4.0),
#  ('130', '330', 4.0),
#  ('342', '249', 3.0),
#  ('543', '947', 4.0),
#  ('401', '473', 1.0),
#  ('214', '856', 4.0),
#  ('936', '995', 3.0),
#  ('472', '72', 5.0),
#  ('268', '735', 3.0),
#  ('366', '17', 5.0),
#  ('328', '752', 2.0),
#  ('6', '435', 4.0),
#  ('815', '229', 3.0),
#  ('135', '943', 3.0),
#  ('606', '827', 3.0),
#  ('268', '399', 3.0),
#  ('188', '54', 4.0),
#  ('191', '754', 3.0),
#  ('189', '483', 5.0),
#  ('825', '12', 5.0),
#  ('250', '331', 3.0),
#  ('621', '417', 3.0),
#  ('542', '627', 3.0),
#  ('683', '271', 3.0),
#  ('249', '125', 3.0),
#  ('922', '217', 3.0),
#  ('72', '1110', 3.0),
#  ('2', '314', 1.0),
#  ('379', '712', 3.0),
#  ('798', '95', 5.0),
#  ('59', '926', 1.0),
#  ('716', '209', 3.0),
#  ('896', '77', 4.0),
#  ('51', '173', 5.0),
#  ('708', '546', 3.0),
#  ('49', '12', 4.0),
#  ('13', '49', 4.0),
#  ('234', '54', 2.0),
#  ('82', '194', 4.0),
#  ('763', '50', 4.0),
#  ('75', '1', 4.0),
#  ('472', '1110', 5.0),
#  ('537', '87', 3.0),
#  ('756', '860', 1.0),
#  ('507', '1237', 5.0),
#  ('393', '62', 4.0),
#  ('854', '528', 4.0),
#  ('90', '966', 5.0),
#  ('791', '306', 5.0),
#  ('114', '357', 4.0),
#  ('343', '67', 3.0),
#  ('805', '769', 2.0),
#  ('279', '229', 4.0),
#  ('60', '423', 4.0),
#  ('380', '956', 4.0),
#  ('16', '705', 5.0),
#  ('94', '1188', 3.0),
#  ('7', '584', 4.0),
#  ('486', '275', 4.0),
#  ('26', '322', 3.0),
#  ('474', '697', 4.0),
#  ('715', '156', 4.0),
#  ('362', '748', 1.0),
#  ('25', '7', 4.0),
#  ('394', '232', 4.0),
#  ('884', '640', 1.0),
#  ('735', '237', 4.0),
#  ('399', '722', 2.0),
#  ('553', '484', 5.0),
#  ('668', '289', 2.0),
#  ('747', '498', 5.0),
#  ('160', '832', 1.0),
#  ('292', '276', 5.0),
#  ('712', '174', 5.0),
#  ('715', '68', 4.0),
#  ('496', '607', 3.0),
#  ('82', '483', 5.0),
#  ('435', '431', 3.0),
#  ('49', '594', 3.0),
#  ('334', '549', 4.0),
#  ('922', '455', 4.0),
#  ('450', '451', 4.0),
#  ('43', '235', 3.0),
#  ('916', '256', 3.0),
#  ('568', '504', 3.0),
#  ('587', '1624', 2.0),
#  ('184', '191', 4.0),
#  ('328', '215', 3.0),
#  ('114', '522', 5.0),
#  ('298', '514', 4.0),
#  ('291', '128', 4.0),
#  ('149', '338', 2.0),
#  ('5', '390', 5.0),
#  ('157', '50', 4.0),
#  ('642', '581', 2.0),
#  ('559', '55', 4.0),
#  ('270', '672', 5.0),
#  ('458', '199', 4.0),
#  ('327', '48', 4.0),
#  ('215', '229', 3.0),
#  ('804', '172', 4.0),
#  ('758', '1019', 4.0),
#  ('901', '63', 5.0),
#  ('551', '926', 2.0),
#  ('663', '876', 3.0),
#  ('830', '554', 5.0),
#  ('271', '498', 5.0),
#  ('342', '15', 3.0),
#  ('403', '477', 4.0),
#  ('405', '1550', 3.0),
#  ('393', '932', 3.0),
#  ('189', '180', 5.0),
#  ('472', '401', 4.0),
#  ('472', '392', 4.0),
#  ('10', '200', 5.0),
#  ('359', '295', 3.0),
#  ('215', '480', 5.0),
#  ('505', '187', 1.0),
#  ('643', '153', 4.0),
#  ('506', '248', 2.0),
#  ('601', '436', 4.0),
#  ('64', '258', 3.0),
#  ('218', '648', 4.0),
#  ('318', '697', 5.0),
#  ('308', '484', 3.0),
#  ('453', '697', 4.0),
#  ('731', '320', 1.0),
#  ('756', '398', 3.0),
#  ('700', '202', 3.0),
#  ('532', '496', 5.0),
#  ('554', '238', 3.0),
#  ('557', '166', 4.0),
#  ('72', '1', 4.0),
#  ('727', '771', 3.0),
#  ('712', '949', 4.0),
#  ('130', '173', 3.0),
#  ('454', '95', 2.0),
#  ('13', '678', 3.0),
#  ('894', '147', 3.0),
#  ('82', '133', 4.0),
#  ('181', '289', 4.0),
#  ('334', '4', 3.0),
#  ('298', '144', 4.0),
#  ('711', '724', 5.0),
#  ('301', '56', 4.0),
#  ('134', '1', 5.0),
#  ('890', '451', 2.0),
#  ('630', '111', 5.0),
#  ('782', '687', 2.0),
#  ('922', '579', 3.0),
#  ('263', '199', 5.0),
#  ('796', '1297', 2.0),
#  ('407', '230', 4.0),
#  ('200', '227', 5.0),
#  ('927', '385', 4.0),
#  ('92', '121', 5.0),
#  ('188', '162', 4.0),
#  ('712', '143', 5.0),
#  ('197', '50', 5.0),
#  ('823', '154', 5.0),
#  ('868', '24', 2.0),
#  ('119', '25', 5.0),
#  ('43', '272', 5.0),
#  ('450', '489', 4.0),
#  ('328', '199', 4.0),
#  ('113', '329', 3.0),
#  ('267', '576', 3.0),
#  ('620', '313', 5.0),
#  ('269', '132', 5.0),
#  ('693', '191', 2.0),
#  ('169', '134', 5.0),
#  ('95', '843', 4.0),
#  ('378', '160', 2.0),
#  ('880', '161', 2.0),
#  ('645', '61', 5.0),
#  ('361', '213', 5.0),
#  ('353', '898', 2.0),
#  ('286', '455', 1.0),
#  ('565', '52', 5.0),
#  ('495', '391', 3.0),
#  ('716', '504', 5.0),
#  ('471', '969', 2.0),
#  ('940', '89', 4.0),
#  ('877', '549', 4.0),
#  ('903', '655', 5.0),
#  ('346', '1210', 3.0),
#  ('303', '5', 2.0),
#  ('332', '123', 4.0),
#  ('825', '595', 3.0),
#  ('616', '328', 3.0),
#  ('417', '99', 4.0),
#  ('548', '898', 1.0),
#  ('727', '282', 4.0),
#  ('630', '640', 1.0),
#  ('292', '653', 4.0),
#  ('497', '163', 2.0),
#  ('23', '181', 4.0),
#  ('178', '222', 4.0),
#  ('645', '709', 3.0),
#  ('805', '806', 4.0),
#  ('275', '142', 2.0),
#  ('648', '4', 1.0),
#  ('18', '89', 3.0),
#  ('795', '1095', 3.0),
#  ('497', '452', 2.0),
#  ('92', '278', 3.0),
#  ('505', '313', 5.0),
#  ('174', '471', 5.0),
#  ('59', '273', 2.0),
#  ('648', '205', 3.0),
#  ('327', '249', 2.0),
#  ('751', '204', 4.0),
#  ('447', '411', 2.0),
#  ('648', '797', 3.0),
#  ('666', '122', 2.0),
#  ('660', '173', 5.0),
#  ('537', '730', 3.0),
#  ('896', '23', 2.0),
#  ('174', '402', 5.0),
#  ('520', '300', 4.0),
#  ('634', '294', 4.0),
#  ('223', '248', 1.0),
#  ('451', '1392', 1.0),
#  ('301', '357', 5.0),
#  ('25', '837', 4.0),
#  ('401', '174', 4.0),
#  ('629', '886', 3.0),
#  ('49', '403', 3.0),
#  ('793', '508', 4.0),
#  ('327', '527', 4.0),
#  ('57', '717', 4.0),
#  ('116', '346', 4.0),
#  ('18', '189', 5.0),
#  ('129', '327', 3.0),
#  ('255', '546', 3.0),
#  ('486', '181', 4.0),
#  ('286', '167', 5.0),
#  ('641', '83', 4.0),
#  ('752', '1024', 3.0),
#  ('10', '502', 4.0),
#  ('557', '875', 4.0),
#  ('13', '42', 4.0),
#  ('74', '245', 3.0),
#  ('308', '214', 2.0),
#  ('782', '1025', 2.0),
#  ('269', '96', 1.0),
#  ('537', '171', 3.0),
#  ('538', '527', 3.0),
#  ('683', '880', 3.0),
#  ('234', '956', 3.0),
#  ('361', '657', 5.0),
#  ('884', '70', 4.0),
#  ('160', '79', 4.0),
#  ('308', '501', 4.0),
#  ('301', '197', 5.0),
#  ('533', '1282', 3.0),
#  ('13', '420', 4.0),
#  ('276', '228', 4.0),
#  ('234', '656', 4.0),
#  ('822', '91', 3.0),
#  ('244', '290', 3.0),
#  ('276', '571', 2.0),
#  ('618', '815', 4.0),
#  ('429', '87', 3.0),
#  ('43', '283', 2.0),
#  ('405', '1439', 1.0),
#  ('234', '166', 5.0),
#  ('92', '408', 4.0),
#  ('314', '71', 5.0),
#  ('617', '17', 1.0),
#  ('181', '1348', 1.0),
#  ('256', '283', 3.0),
#  ('295', '843', 4.0),
#  ('833', '614', 2.0),
#  ('854', '846', 3.0),
#  ('206', '1430', 1.0),
#  ('119', '194', 5.0),
#  ('222', '1045', 3.0),
#  ('85', '506', 4.0),
#  ('316', '127', 2.0),
#  ('316', '323', 1.0),
#  ('567', '212', 2.0),
#  ('435', '635', 3.0),
#  ('823', '135', 4.0),
#  ('78', '298', 3.0),
#  ('297', '195', 1.0),
#  ('560', '1073', 3.0),
#  ('521', '184', 4.0),
#  ('405', '1422', 1.0),
#  ('880', '1041', 4.0),
#  ('880', '356', 4.0),
#  ('537', '689', 1.0),
#  ('326', '8', 4.0),
#  ('268', '380', 2.0),
#  ('896', '525', 5.0),
#  ('919', '1048', 3.0),
#  ('279', '10', 4.0),
#  ('766', '179', 4.0),
#  ('318', '628', 4.0),
#  ('276', '751', 4.0),
#  ('369', '948', 2.0),
#  ('698', '86', 2.0),
#  ('222', '222', 4.0),
#  ('936', '756', 4.0),
#  ('831', '307', 2.0),
#  ('109', '72', 5.0),
#  ('130', '271', 5.0),
#  ('745', '425', 4.0),
#  ('330', '58', 5.0),
#  ('535', '1124', 4.0),
#  ('320', '774', 4.0),
#  ('424', '288', 1.0),
#  ('16', '583', 4.0),
#  ('128', '159', 4.0),
#  ('739', '176', 1.0),
#  ('416', '1160', 4.0),
#  ('606', '138', 3.0),
#  ('665', '687', 2.0),
#  ('664', '53', 3.0),
#  ('476', '959', 3.0),
#  ('758', '898', 3.0),
#  ('851', '979', 3.0),
#  ('263', '82', 4.0),
#  ('608', '190', 4.0),
#  ('551', '84', 1.0),
#  ('130', '158', 5.0),
#  ('747', '497', 5.0),
#  ('617', '201', 1.0),
#  ('532', '1300', 3.0),
#  ('236', '1102', 4.0),
#  ('521', '172', 3.0),
#  ('406', '521', 3.0),
#  ('268', '164', 2.0),
#  ('13', '135', 5.0),
#  ('727', '802', 2.0),
#  ('385', '305', 4.0),
#  ('682', '318', 4.0),
#  ('566', '7', 4.0),
#  ('36', '875', 3.0),
#  ('174', '451', 5.0),
#  ('631', '338', 2.0),
#  ('300', '872', 5.0),
#  ('766', '205', 5.0),
#  ('6', '177', 4.0),
#  ('83', '191', 4.0),
#  ('328', '916', 2.0),
#  ('264', '202', 5.0),
#  ('773', '216', 4.0),
#  ('537', '727', 2.0),
#  ('291', '97', 4.0),
#  ('271', '792', 4.0),
#  ('886', '23', 4.0),
#  ('663', '286', 3.0),
#  ('181', '93', 1.0),
#  ('233', '177', 4.0),
#  ('846', '1107', 4.0),
#  ('117', '96', 5.0),
#  ('95', '73', 4.0),
#  ('712', '294', 4.0),
#  ('416', '785', 3.0),
#  ('547', '354', 4.0),
#  ('815', '215', 5.0),
#  ('160', '955', 4.0),
#  ('846', '36', 2.0),
#  ('457', '559', 4.0),
#  ('203', '283', 5.0),
#  ('848', '121', 4.0),
#  ('894', '1009', 4.0),
#  ('450', '821', 2.0),
#  ('778', '623', 1.0),
#  ('320', '742', 4.0),
#  ('655', '1113', 3.0),
#  ('59', '524', 3.0),
#  ('409', '153', 4.0),
#  ('431', '690', 3.0),
#  ('593', '781', 3.0),
#  ('410', '312', 2.0),
#  ('59', '708', 4.0),
#  ('767', '615', 4.0),
#  ('296', '204', 5.0),
#  ('727', '435', 3.0),
#  ('500', '325', 3.0),
#  ('233', '614', 4.0),
#  ('282', '879', 2.0),
#  ('896', '588', 5.0),
#  ('764', '321', 1.0),
#  ('648', '175', 3.0),
#  ('181', '758', 1.0),
#  ('263', '465', 4.0),
#  ('308', '646', 5.0),
#  ('4', '356', 3.0),
#  ('85', '58', 4.0),
#  ('919', '148', 3.0),
#  ('796', '300', 4.0),
#  ('708', '313', 5.0),
#  ('886', '589', 3.0),
#  ('432', '411', 3.0),
#  ('315', '271', 3.0),
#  ('624', '295', 3.0),
#  ('92', '1194', 4.0),
#  ('7', '509', 5.0),
#  ('426', '754', 1.0),
#  ('490', '224', 2.0),
#  ('305', '12', 5.0),
#  ('269', '475', 5.0),
#  ('664', '717', 1.0),
#  ('136', '298', 4.0),
#  ('72', '198', 5.0),
#  ('567', '478', 5.0),
#  ('782', '984', 2.0),
#  ('149', '337', 2.0),
#  ('378', '428', 3.0),
#  ('881', '1033', 1.0),
#  ('196', '428', 4.0),
#  ('933', '56', 5.0),
#  ('387', '203', 4.0),
#  ('355', '872', 4.0),
#  ('894', '61', 4.0),
#  ('795', '70', 3.0),
#  ('778', '281', 2.0),
#  ('707', '641', 1.0),
#  ('334', '306', 4.0),
#  ('638', '187', 2.0),
#  ('503', '963', 5.0),
#  ('13', '662', 5.0),
#  ('323', '245', 2.0),
#  ('130', '343', 4.0),
#  ('886', '380', 3.0),
#  ('388', '742', 5.0),
#  ('194', '23', 4.0),
#  ('825', '986', 5.0),
#  ('698', '659', 3.0),
#  ('897', '281', 4.0),
#  ('721', '435', 4.0),
#  ('682', '358', 3.0),
#  ('422', '1007', 4.0),
#  ('727', '1446', 3.0),
#  ('57', '1016', 4.0),
#  ('446', '303', 2.0),
#  ('451', '872', 2.0),
#  ('347', '204', 4.0),
#  ('295', '88', 4.0),
#  ('267', '77', 3.0),
#  ('269', '120', 1.0),
#  ('28', '447', 3.0),
#  ('870', '813', 4.0),
#  ('881', '9', 3.0),
#  ('450', '498', 3.0),
#  ('621', '65', 3.0),
#  ('94', '391', 3.0),
#  ('773', '386', 3.0),
#  ('450', '101', 5.0),
#  ('416', '1074', 5.0),
#  ('309', '324', 3.0),
#  ('666', '197', 4.0),
#  ('894', '60', 5.0),
#  ('234', '371', 3.0),
#  ('437', '1063', 5.0),
#  ('7', '39', 5.0),
#  ('194', '466', 4.0),
#  ('74', '276', 4.0),
#  ('383', '319', 2.0),
#  ('454', '385', 3.0),
#  ('882', '455', 3.0),
#  ('286', '749', 3.0),
#  ('685', '302', 3.0),
#  ('73', '154', 5.0),
#  ('1', '54', 3.0),
#  ('21', '258', 4.0),
#  ('847', '1', 3.0),
#  ('198', '180', 3.0),
#  ('788', '175', 3.0),
#  ('387', '246', 3.0),
#  ('259', '173', 4.0),
#  ('450', '942', 5.0),
#  ('607', '100', 4.0),
#  ('621', '2', 3.0),
#  ('131', '248', 3.0),
#  ('881', '443', 5.0),
#  ('269', '194', 5.0),
#  ('282', '338', 3.0),
#  ('879', '237', 4.0),
#  ('636', '118', 5.0),
#  ('780', '433', 1.0),
#  ('618', '427', 5.0),
#  ('308', '686', 4.0),
#  ('55', '273', 5.0),
#  ('71', '154', 3.0),
#  ('629', '100', 5.0),
#  ('648', '181', 5.0),
#  ('49', '294', 1.0),
#  ('406', '1065', 2.0),
#  ('50', '268', 4.0),
#  ('835', '526', 3.0),
#  ('240', '242', 5.0),
#  ('405', '69', 4.0),
#  ('316', '180', 4.0),
#  ('883', '367', 5.0),
#  ('324', '310', 4.0),
#  ('254', '240', 1.0),
#  ('159', '25', 5.0),
#  ('363', '121', 2.0),
#  ('59', '1048', 4.0),
#  ('295', '561', 5.0),
#  ('343', '747', 4.0),
#  ('168', '1278', 3.0),
#  ('521', '474', 3.0),
#  ('239', '652', 5.0),
#  ('940', '347', 3.0),
#  ('533', '1174', 3.0),
#  ('862', '12', 5.0),
#  ('346', '1110', 1.0),
#  ('262', '90', 4.0),
#  ('70', '684', 3.0),
#  ('361', '59', 4.0),
#  ('294', '840', 3.0),
#  ('43', '699', 4.0),
#  ('421', '98', 5.0),
#  ('260', '682', 4.0),
#  ('82', '71', 4.0),
#  ('660', '1020', 4.0),
#  ('592', '742', 4.0),
#  ('815', '121', 2.0),
#  ('279', '558', 4.0),
#  ('537', '311', 3.0),
#  ('181', '740', 2.0),
#  ('365', '235', 2.0),
#  ('892', '7', 4.0),
#  ('10', '245', 4.0),
#  ('301', '118', 4.0),
#  ('460', '149', 4.0),
#  ('207', '58', 3.0),
#  ('556', '482', 5.0),
#  ('588', '283', 4.0),
#  ('807', '679', 4.0),
#  ('59', '1113', 4.0),
#  ('373', '727', 4.0),
#  ('380', '665', 2.0),
#  ('210', '821', 3.0),
#  ('542', '864', 3.0),
#  ('92', '409', 3.0),
#  ('58', '709', 5.0),
#  ('401', '591', 3.0),
#  ('707', '956', 5.0),
#  ('486', '319', 3.0),
#  ('586', '566', 3.0),
#  ('848', '42', 2.0),
#  ('659', '1119', 4.0),
#  ('525', '762', 4.0),
#  ('151', '136', 4.0),
#  ('880', '769', 3.0),
#  ('440', '310', 3.0),
#  ('246', '675', 4.0),
#  ('405', '695', 1.0),
#  ('102', '831', 2.0),
#  ('389', '50', 5.0),
#  ('606', '576', 3.0),
#  ('449', '269', 5.0),
#  ('829', '1120', 2.0),
#  ('222', '373', 3.0),
#  ('683', '272', 4.0),
#  ('429', '747', 3.0),
#  ('847', '742', 3.0),
#  ('262', '365', 4.0),
#  ('181', '1324', 1.0),
#  ('650', '493', 4.0),
#  ('804', '756', 3.0),
#  ('293', '45', 5.0),
#  ('293', '245', 3.0),
#  ('144', '187', 4.0),
#  ('131', '744', 4.0),
#  ('690', '742', 3.0),
#  ('883', '882', 4.0),
#  ('3', '324', 2.0),
#  ('298', '419', 5.0),
#  ('479', '463', 4.0),
#  ('530', '204', 4.0),
#  ('71', '357', 5.0),
#  ('658', '1101', 4.0),
#  ('561', '739', 2.0),
#  ('709', '27', 3.0),
#  ('534', '121', 4.0),
#  ('269', '213', 5.0),
#  ('588', '318', 4.0),
#  ('849', '298', 5.0),
#  ('648', '586', 3.0),
#  ('618', '214', 2.0),
#  ('10', '385', 4.0),
#  ('327', '173', 4.0),
#  ('577', '795', 3.0),
#  ('590', '676', 4.0),
#  ('524', '517', 4.0),
#  ('45', '756', 2.0),
#  ('927', '820', 4.0),
#  ('747', '428', 3.0),
#  ('747', '135', 5.0),
#  ('303', '99', 4.0),
#  ('682', '651', 4.0),
#  ('16', '208', 5.0),
#  ('873', '339', 3.0),
#  ('653', '118', 3.0),
#  ('497', '420', 3.0),
#  ('693', '378', 2.0),
#  ('216', '1218', 3.0),
#  ('7', '134', 4.0),
#  ('798', '87', 3.0),
#  ('484', '29', 3.0),
#  ('741', '164', 3.0),
#  ('896', '257', 4.0),
#  ('833', '347', 3.0),
#  ('184', '124', 5.0),
#  ('233', '117', 3.0),
#  ('193', '443', 4.0),
#  ('786', '15', 3.0),
#  ('286', '329', 4.0),
#  ('254', '575', 3.0),
#  ('864', '53', 4.0),
#  ('329', '515', 4.0),
#  ('221', '384', 3.0),
#  ('299', '179', 4.0),
#  ('862', '252', 3.0),
#  ('5', '257', 5.0),
#  ('236', '289', 4.0),
#  ('536', '183', 3.0),
#  ('776', '174', 5.0),
#  ('405', '570', 1.0),
#  ('825', '405', 5.0),
#  ('682', '245', 3.0),
#  ('474', '69', 5.0),
#  ('153', '568', 4.0),
#  ('815', '542', 4.0),
#  ('130', '68', 5.0),
#  ('655', '210', 3.0),
#  ('506', '218', 3.0),
#  ('409', '209', 5.0),
#  ('330', '209', 3.0),
#  ('332', '229', 5.0),
#  ('178', '62', 4.0),
#  ('162', '28', 4.0),
#  ('795', '154', 3.0),
#  ('442', '286', 2.0),
#  ('497', '510', 3.0),
#  ('709', '182', 4.0),
#  ('273', '896', 4.0),
#  ('888', '280', 3.0),
#  ('721', '145', 4.0),
#  ('303', '1230', 1.0),
#  ('218', '98', 5.0),
#  ('522', '654', 4.0),
#  ('15', '220', 4.0),
#  ('203', '50', 5.0),
#  ('90', '879', 3.0),
#  ('886', '159', 2.0),
#  ('795', '407', 3.0),
#  ('804', '615', 5.0),
#  ('805', '827', 4.0),
#  ('646', '877', 3.0),
#  ('363', '658', 3.0),
#  ('848', '133', 4.0),
#  ('222', '715', 2.0),
#  ('298', '864', 3.0),
#  ('770', '924', 5.0),
#  ('7', '157', 5.0),
#  ('569', '546', 3.0),
#  ('420', '19', 3.0),
#  ('378', '1232', 3.0),
#  ('136', '318', 5.0),
#  ('130', '5', 4.0),
#  ('781', '245', 2.0),
#  ('151', '89', 5.0),
#  ('714', '111', 3.0),
#  ('930', '240', 1.0),
#  ('854', '537', 3.0),
#  ('451', '329', 4.0),
#  ('279', '832', 3.0),
#  ('852', '118', 4.0),
#  ('716', '1124', 3.0),
#  ('221', '173', 4.0),
#  ('769', '748', 2.0),
#  ('743', '340', 3.0),
#  ('319', '750', 3.0),
#  ('650', '510', 3.0),
#  ('524', '488', 4.0),
#  ('923', '181', 5.0),
#  ('741', '673', 4.0),
#  ('13', '780', 1.0),
#  ('733', '762', 4.0),
#  ('270', '253', 5.0),
#  ('271', '97', 5.0),
#  ('642', '165', 4.0),
#  ('545', '94', 3.0),
#  ('911', '87', 5.0),
#  ('478', '222', 2.0),
#  ('295', '79', 4.0),
#  ('87', '510', 5.0),
#  ('470', '93', 4.0),
#  ('271', '707', 4.0),
#  ('697', '301', 5.0),
#  ('676', '13', 1.0),
#  ('500', '125', 3.0),
#  ('804', '513', 5.0),
#  ('712', '746', 4.0),
#  ('596', '300', 4.0),
#  ('551', '1011', 5.0),
#  ('777', '153', 1.0),
#  ('534', '455', 5.0),
#  ('94', '824', 4.0),
#  ('804', '231', 4.0),
#  ('270', '164', 5.0),
#  ('286', '250', 4.0),
#  ('342', '236', 3.0),
#  ('44', '82', 4.0),
#  ('467', '455', 3.0),
#  ('871', '147', 5.0),
#  ('216', '274', 3.0),
#  ('749', '9', 3.0),
#  ('815', '523', 4.0),
#  ('372', '79', 5.0),
#  ('301', '426', 4.0),
#  ('292', '320', 5.0),
#  ('151', '356', 2.0),
#  ('244', '790', 4.0),
#  ('815', '50', 5.0),
#  ('599', '535', 4.0),
#  ('518', '14', 3.0),
#  ('181', '978', 1.0),
#  ('686', '969', 5.0),
#  ('16', '504', 5.0),
#  ('43', '298', 4.0),
#  ('505', '755', 3.0),
#  ('104', '100', 4.0),
#  ('336', '1496', 1.0),
#  ('95', '193', 3.0),
#  ('519', '1434', 5.0),
#  ('592', '265', 4.0),
#  ('262', '790', 3.0),
#  ('92', '684', 3.0),
#  ('844', '168', 4.0),
#  ('903', '196', 4.0),
#  ('901', '94', 4.0),
#  ('223', '866', 4.0),
#  ('101', '819', 1.0),
#  ('378', '194', 4.0),
#  ('121', '315', 4.0),
#  ('804', '448', 3.0),
#  ('429', '170', 5.0),
#  ('90', '433', 3.0),
#  ('102', '88', 3.0),
#  ('276', '1471', 2.0),
#  ('883', '707', 3.0),
#  ('279', '1239', 1.0),
#  ('864', '116', 4.0),
#  ('95', '510', 4.0),
#  ('102', '684', 2.0),
#  ('333', '186', 4.0),
#  ('495', '82', 5.0),
#  ('854', '493', 5.0),
#  ('313', '164', 3.0),
#  ('536', '679', 4.0),
#  ('181', '19', 1.0),
#  ('185', '269', 5.0),
#  ('314', '216', 3.0),
#  ('314', '623', 5.0),
#  ('416', '357', 5.0),
#  ('180', '258', 5.0),
#  ('423', '898', 4.0),
#  ('389', '997', 3.0),
#  ('207', '476', 2.0),
#  ('18', '212', 5.0),
#  ('639', '661', 4.0),
#  ('737', '186', 5.0),
#  ('324', '14', 5.0),
#  ('825', '250', 5.0),
#  ('332', '1047', 3.0),
#  ('761', '457', 1.0),
#  ('219', '879', 4.0),
#  ('881', '1118', 3.0),
#  ('149', '333', 1.0),
#  ('327', '89', 4.0),
#  ('259', '1074', 3.0),
#  ('721', '1', 5.0),
#  ('177', '527', 4.0),
#  ('897', '371', 2.0),
#  ('378', '172', 4.0),
#  ('417', '17', 4.0),
#  ('639', '1065', 1.0),
#  ('393', '291', 4.0),
#  ('269', '232', 1.0),
#  ('339', '126', 4.0),
#  ('370', '323', 2.0),
#  ('880', '1049', 3.0),
#  ('62', '7', 4.0),
#  ('276', '1019', 5.0),
#  ('115', '177', 5.0),
#  ('561', '14', 3.0),
#  ('757', '97', 4.0),
#  ('641', '124', 4.0),
#  ('848', '739', 5.0),
#  ('585', '638', 4.0),
#  ('401', '318', 4.0),
#  ('655', '1368', 5.0),
#  ('92', '452', 2.0),
#  ('748', '732', 4.0),
#  ('625', '50', 5.0),
#  ('296', '181', 5.0),
#  ('601', '1296', 1.0),
#  ('527', '628', 3.0),
#  ('145', '688', 4.0),
#  ('698', '50', 5.0),
#  ('263', '153', 3.0),
#  ('151', '1197', 5.0),
#  ('830', '100', 5.0),
#  ('927', '64', 5.0),
#  ('151', '609', 4.0),
#  ('906', '628', 5.0),
#  ('28', '436', 5.0),
#  ('863', '300', 5.0),
#  ('805', '164', 3.0),
#  ('359', '50', 5.0),
#  ('303', '1222', 3.0),
#  ('141', '1283', 3.0),
#  ('34', '332', 5.0),
#  ('896', '572', 2.0),
#  ('792', '844', 4.0),
#  ('612', '300', 4.0),
#  ('703', '259', 1.0),
#  ('293', '367', 2.0),
#  ('659', '837', 3.0),
#  ('699', '683', 3.0),
#  ('64', '216', 4.0),
#  ('405', '1405', 1.0),
#  ('152', '716', 5.0),
#  ('11', '191', 4.0),
#  ('537', '543', 5.0),
#  ('49', '238', 4.0),
#  ('495', '1263', 4.0),
#  ('533', '294', 4.0),
#  ('868', '524', 3.0),
#  ('840', '639', 4.0),
#  ('932', '163', 4.0),
#  ('852', '681', 4.0),
#  ('505', '133', 5.0),
#  ('121', '405', 2.0),
#  ('847', '104', 3.0),
#  ('404', '750', 3.0),
#  ('862', '179', 5.0),
#  ('293', '176', 4.0),
#  ('25', '177', 3.0),
#  ('450', '715', 3.0),
#  ('8', '689', 4.0),
#  ('774', '182', 4.0),
#  ('859', '111', 4.0),
#  ('804', '616', 3.0),
#  ('130', '117', 5.0),
#  ('299', '508', 4.0),
#  ('345', '676', 4.0),
#  ('503', '134', 5.0),
#  ('586', '181', 4.0),
#  ('632', '550', 2.0),
#  ('454', '250', 4.0),
#  ...]

# %%
trainset

# %%
algo.fit(trainset)
predictions = algo.test(testset)

# %%
from surprise import accuracy

# %%
predictions
# Out:
# [Prediction(uid='254', iid='50', r_ui=5.0, est=4.094783087500591, details={'was_impossible': False}),
#  Prediction(uid='825', iid='1028', r_ui=3.0, est=3.5562106485325193, details={'was_impossible': False}),
#  Prediction(uid='932', iid='177', r_ui=4.0, est=4.177043485884737, details={'was_impossible': False}),
#  Prediction(uid='383', iid='464', r_ui=4.0, est=4.231578303703756, details={'was_impossible': False}),
#  Prediction(uid='155', iid='245', r_ui=2.0, est=2.7037228244003377, details={'was_impossible': False}),
#  Prediction(uid='495', iid='4', r_ui=3.0, est=3.7869156600198077, details={'was_impossible': False}),
#  Prediction(uid='640', iid='941', r_ui=5.0, est=3.823356130907558, details={'was_impossible': False}),
#  Prediction(uid='543', iid='443', r_ui=4.0, est=3.597388242101722, details={'was_impossible': False}),
#  Prediction(uid='326', iid='550', r_ui=5.0, est=2.902935866281436, details={'was_impossible': False}),
#  Prediction(uid='223', iid='1052', r_ui=1.0, est=2.6965963104572173, details={'was_impossible': False}),
#  Prediction(uid='248', iid='153', r_ui=3.0, est=3.813927977703758, details={'was_impossible': False}),
#  Prediction(uid='239', iid='205', r_ui=3.0, est=4.576744674315608, details={'was_impossible': False}),
#  Prediction(uid='263', iid='168', r_ui=5.0, est=4.312571901346458, details={'was_impossible': False}),
#  Prediction(uid='305', iid='1512', r_ui=3.0, est=3.260902863606375, details={'was_impossible': False}),
#  Prediction(uid='1', iid='49', r_ui=3.0, est=3.651480811381878, details={'was_impossible': False}),
#  Prediction(uid='207', iid='144', r_ui=3.0, est=3.3011679728764816, details={'was_impossible': False}),
#  Prediction(uid='498', iid='1404', r_ui=3.0, est=2.7328254109354755, details={'was_impossible': False}),
#  Prediction(uid='592', iid='323', r_ui=1.0, est=2.15050982260167, details={'was_impossible': False}),
#  Prediction(uid='359', iid='181', r_ui=5.0, est=4.128125286739544, details={'was_impossible': False}),
#  Prediction(uid='164', iid='248', r_ui=4.0, est=4.461648176696926, details={'was_impossible': False}),
#  Prediction(uid='276', iid='325', r_ui=3.0, est=2.7134035724579983, details={'was_impossible': False}),
#  Prediction(uid='92', iid='356', r_ui=3.0, est=3.098073561332263, details={'was_impossible': False}),
#  Prediction(uid='416', iid='997', r_ui=3.0, est=2.7280682096529754, details={'was_impossible': False}),
#  Prediction(uid='806', iid='484', r_ui=4.0, est=4.326323390488264, details={'was_impossible': False}),
#  Prediction(uid='201', iid='511', r_ui=3.0, est=3.9086173822564194, details={'was_impossible': False}),
#  Prediction(uid='756', iid='71', r_ui=3.0, est=3.5006116135958454, details={'was_impossible': False}),
#  Prediction(uid='429', iid='45', r_ui=3.0, est=4.203809751581721, details={'was_impossible': False}),
#  Prediction(uid='535', iid='1098', r_ui=5.0, est=3.7958898586844225, details={'was_impossible': False}),
#  Prediction(uid='835', iid='486', r_ui=4.0, est=4.056338537234217, details={'was_impossible': False}),
#  Prediction(uid='572', iid='1010', r_ui=2.0, est=3.253998961833475, details={'was_impossible': False}),
#  Prediction(uid='936', iid='251', r_ui=4.0, est=4.657719162541449, details={'was_impossible': False}),
#  Prediction(uid='639', iid='174', r_ui=4.0, est=3.4491438633768654, details={'was_impossible': False}),
#  Prediction(uid='568', iid='606', r_ui=5.0, est=3.347104289369156, details={'was_impossible': False}),
#  Prediction(uid='834', iid='762', r_ui=4.0, est=3.7295343649926664, details={'was_impossible': False}),
#  Prediction(uid='864', iid='143', r_ui=4.0, est=4.05502791805059, details={'was_impossible': False}),
#  Prediction(uid='823', iid='128', r_ui=2.0, est=3.9099271432255813, details={'was_impossible': False}),
#  Prediction(uid='655', iid='288', r_ui=3.0, est=2.4850922023430684, details={'was_impossible': False}),
#  Prediction(uid='552', iid='411', r_ui=3.0, est=2.8968118543992394, details={'was_impossible': False}),
#  Prediction(uid='659', iid='654', r_ui=4.0, est=4.218404932136525, details={'was_impossible': False}),
#  Prediction(uid='158', iid='56', r_ui=5.0, est=4.530158291552272, details={'was_impossible': False}),
#  Prediction(uid='498', iid='12', r_ui=4.0, est=3.6019217766260194, details={'was_impossible': False}),
#  Prediction(uid='870', iid='284', r_ui=2.0, est=2.8424053949871935, details={'was_impossible': False}),
#  Prediction(uid='58', iid='684', r_ui=4.0, est=3.718509102169704, details={'was_impossible': False}),
#  Prediction(uid='466', iid='651', r_ui=3.0, est=3.890694729633577, details={'was_impossible': False}),
#  Prediction(uid='886', iid='15', r_ui=3.0, est=3.3696711278628273, details={'was_impossible': False}),
#  Prediction(uid='561', iid='141', r_ui=2.0, est=2.740843287179233, details={'was_impossible': False}),
#  Prediction(uid='833', iid='577', r_ui=1.0, est=1.7091208127852673, details={'was_impossible': False}),
#  Prediction(uid='336', iid='121', r_ui=4.0, est=3.566855054726668, details={'was_impossible': False}),
#  Prediction(uid='387', iid='593', r_ui=3.0, est=3.4572640375342267, details={'was_impossible': False}),
#  Prediction(uid='639', iid='97', r_ui=1.0, est=3.286735963361398, details={'was_impossible': False}),
#  Prediction(uid='59', iid='68', r_ui=2.0, est=3.896268585917458, details={'was_impossible': False}),
#  Prediction(uid='263', iid='143', r_ui=5.0, est=3.9092321696837367, details={'was_impossible': False}),
#  Prediction(uid='7', iid='652', r_ui=3.0, est=4.0365818766297945, details={'was_impossible': False}),
#  Prediction(uid='11', iid='15', r_ui=5.0, est=3.522166922807255, details={'was_impossible': False}),
#  Prediction(uid='577', iid='403', r_ui=4.0, est=3.5321857607897424, details={'was_impossible': False}),
#  Prediction(uid='545', iid='510', r_ui=3.0, est=3.766816024199244, details={'was_impossible': False}),
#  Prediction(uid='256', iid='387', r_ui=4.0, est=4.155213013420869, details={'was_impossible': False}),
#  Prediction(uid='333', iid='520', r_ui=4.0, est=4.0909494403636195, details={'was_impossible': False}),
#  Prediction(uid='887', iid='1413', r_ui=4.0, est=3.9603740020578395, details={'was_impossible': False}),
#  Prediction(uid='715', iid='90', r_ui=5.0, est=2.67006300679956, details={'was_impossible': False}),
#  Prediction(uid='716', iid='48', r_ui=5.0, est=4.214904684598525, details={'was_impossible': False}),
#  Prediction(uid='489', iid='300', r_ui=5.0, est=4.418401117382069, details={'was_impossible': False}),
#  Prediction(uid='246', iid='250', r_ui=4.0, est=2.988449308118065, details={'was_impossible': False}),
#  Prediction(uid='387', iid='100', r_ui=5.0, est=4.108881874225035, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1012', r_ui=3.0, est=2.997041874786736, details={'was_impossible': False}),
#  Prediction(uid='543', iid='89', r_ui=4.0, est=3.9104386147437005, details={'was_impossible': False}),
#  Prediction(uid='161', iid='215', r_ui=2.0, est=2.8700556853454287, details={'was_impossible': False}),
#  Prediction(uid='94', iid='68', r_ui=4.0, est=3.512855639609837, details={'was_impossible': False}),
#  Prediction(uid='632', iid='7', r_ui=3.0, est=3.5885689971304213, details={'was_impossible': False}),
#  Prediction(uid='440', iid='937', r_ui=5.0, est=4.136752546513611, details={'was_impossible': False}),
#  Prediction(uid='574', iid='319', r_ui=5.0, est=3.29812878942528, details={'was_impossible': False}),
#  Prediction(uid='56', iid='67', r_ui=2.0, est=3.870236423078829, details={'was_impossible': False}),
#  Prediction(uid='790', iid='217', r_ui=4.0, est=2.7827711830161266, details={'was_impossible': False}),
#  Prediction(uid='889', iid='124', r_ui=4.0, est=3.782627056998796, details={'was_impossible': False}),
#  Prediction(uid='312', iid='654', r_ui=5.0, est=4.643614075890536, details={'was_impossible': False}),
#  Prediction(uid='193', iid='33', r_ui=3.0, est=3.2721477195388333, details={'was_impossible': False}),
#  Prediction(uid='704', iid='222', r_ui=3.0, est=3.582965202745253, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1216', r_ui=4.0, est=2.839350143241427, details={'was_impossible': False}),
#  Prediction(uid='311', iid='468', r_ui=4.0, est=3.272328401674952, details={'was_impossible': False}),
#  Prediction(uid='53', iid='257', r_ui=4.0, est=3.7104048094640927, details={'was_impossible': False}),
#  Prediction(uid='7', iid='560', r_ui=3.0, est=3.1628592766560915, details={'was_impossible': False}),
#  Prediction(uid='403', iid='237', r_ui=5.0, est=3.7801351119080535, details={'was_impossible': False}),
#  Prediction(uid='347', iid='1012', r_ui=4.0, est=3.993670263005437, details={'was_impossible': False}),
#  Prediction(uid='588', iid='815', r_ui=4.0, est=3.4935469843009224, details={'was_impossible': False}),
#  Prediction(uid='270', iid='596', r_ui=5.0, est=4.173195979617716, details={'was_impossible': False}),
#  Prediction(uid='164', iid='276', r_ui=3.0, est=4.520593597186595, details={'was_impossible': False}),
#  Prediction(uid='49', iid='258', r_ui=2.0, est=2.574767788714347, details={'was_impossible': False}),
#  Prediction(uid='399', iid='379', r_ui=3.0, est=2.634382236626352, details={'was_impossible': False}),
#  Prediction(uid='732', iid='332', r_ui=5.0, est=3.6238884358146515, details={'was_impossible': False}),
#  Prediction(uid='411', iid='174', r_ui=4.0, est=4.295660778853856, details={'was_impossible': False}),
#  Prediction(uid='94', iid='418', r_ui=3.0, est=3.63352825151483, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1073', r_ui=3.0, est=3.776601125019208, details={'was_impossible': False}),
#  Prediction(uid='318', iid='405', r_ui=2.0, est=3.663404248677564, details={'was_impossible': False}),
#  Prediction(uid='758', iid='186', r_ui=5.0, est=4.0554731937626975, details={'was_impossible': False}),
#  Prediction(uid='478', iid='98', r_ui=5.0, est=4.112050533946513, details={'was_impossible': False}),
#  Prediction(uid='194', iid='153', r_ui=3.0, est=3.4028165625240665, details={'was_impossible': False}),
#  Prediction(uid='293', iid='708', r_ui=3.0, est=3.037156742485697, details={'was_impossible': False}),
#  Prediction(uid='255', iid='222', r_ui=3.0, est=2.897159936727301, details={'was_impossible': False}),
#  Prediction(uid='145', iid='1210', r_ui=1.0, est=2.5604076144067904, details={'was_impossible': False}),
#  Prediction(uid='942', iid='878', r_ui=4.0, est=2.9563927240225407, details={'was_impossible': False}),
#  Prediction(uid='870', iid='699', r_ui=3.0, est=3.5667704099397954, details={'was_impossible': False}),
#  Prediction(uid='409', iid='205', r_ui=3.0, est=3.5935056427867007, details={'was_impossible': False}),
#  Prediction(uid='918', iid='135', r_ui=1.0, est=3.296405856709786, details={'was_impossible': False}),
#  Prediction(uid='250', iid='480', r_ui=5.0, est=4.63664835043945, details={'was_impossible': False}),
#  Prediction(uid='546', iid='895', r_ui=3.0, est=3.8116449555334664, details={'was_impossible': False}),
#  Prediction(uid='363', iid='231', r_ui=1.0, est=1.7266137950112328, details={'was_impossible': False}),
#  Prediction(uid='179', iid='353', r_ui=1.0, est=2.1346044807225493, details={'was_impossible': False}),
#  Prediction(uid='103', iid='126', r_ui=5.0, est=3.763965458643782, details={'was_impossible': False}),
#  Prediction(uid='867', iid='51', r_ui=3.0, est=3.6447245985931596, details={'was_impossible': False}),
#  Prediction(uid='561', iid='164', r_ui=2.0, est=2.9212898762482307, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1349', r_ui=1.0, est=1.7517635751836815, details={'was_impossible': False}),
#  Prediction(uid='506', iid='749', r_ui=4.0, est=3.327352657909123, details={'was_impossible': False}),
#  Prediction(uid='234', iid='1456', r_ui=4.0, est=3.147687089317247, details={'was_impossible': False}),
#  Prediction(uid='497', iid='184', r_ui=3.0, est=3.067042279109825, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1590', r_ui=3.0, est=2.926288694919387, details={'was_impossible': False}),
#  Prediction(uid='495', iid='143', r_ui=1.0, est=4.725088203927134, details={'was_impossible': False}),
#  Prediction(uid='902', iid='1016', r_ui=2.0, est=2.87532190423136, details={'was_impossible': False}),
#  Prediction(uid='883', iid='1171', r_ui=5.0, est=3.320560403805678, details={'was_impossible': False}),
#  Prediction(uid='558', iid='116', r_ui=5.0, est=4.0517378969711695, details={'was_impossible': False}),
#  Prediction(uid='693', iid='604', r_ui=3.0, est=3.3483110768037196, details={'was_impossible': False}),
#  Prediction(uid='640', iid='201', r_ui=4.0, est=4.377319921988228, details={'was_impossible': False}),
#  Prediction(uid='450', iid='76', r_ui=3.0, est=3.6943753504488903, details={'was_impossible': False}),
#  Prediction(uid='634', iid='300', r_ui=3.0, est=3.903769886451821, details={'was_impossible': False}),
#  Prediction(uid='822', iid='95', r_ui=4.0, est=3.667057063632828, details={'was_impossible': False}),
#  Prediction(uid='239', iid='304', r_ui=1.0, est=4.017410389542497, details={'was_impossible': False}),
#  Prediction(uid='276', iid='653', r_ui=5.0, est=3.8349626506900463, details={'was_impossible': False}),
#  Prediction(uid='916', iid='186', r_ui=3.0, est=3.848732079332392, details={'was_impossible': False}),
#  Prediction(uid='917', iid='121', r_ui=1.0, est=3.5737618709310346, details={'was_impossible': False}),
#  Prediction(uid='406', iid='675', r_ui=4.0, est=3.716033053655873, details={'was_impossible': False}),
#  Prediction(uid='194', iid='4', r_ui=4.0, est=3.1341687088169317, details={'was_impossible': False}),
#  Prediction(uid='894', iid='148', r_ui=3.0, est=3.4723846075541425, details={'was_impossible': False}),
#  Prediction(uid='56', iid='172', r_ui=5.0, est=4.430476279118348, details={'was_impossible': False}),
#  Prediction(uid='230', iid='98', r_ui=5.0, est=4.192219782611039, details={'was_impossible': False}),
#  Prediction(uid='749', iid='139', r_ui=4.0, est=3.1774799673484977, details={'was_impossible': False}),
#  Prediction(uid='758', iid='1025', r_ui=3.0, est=3.455928179239655, details={'was_impossible': False}),
#  Prediction(uid='816', iid='323', r_ui=4.0, est=3.6624996837485404, details={'was_impossible': False}),
#  Prediction(uid='433', iid='59', r_ui=5.0, est=3.750146072951684, details={'was_impossible': False}),
#  Prediction(uid='293', iid='685', r_ui=3.0, est=2.5216354152590292, details={'was_impossible': False}),
#  Prediction(uid='60', iid='660', r_ui=4.0, est=4.154898651007339, details={'was_impossible': False}),
#  Prediction(uid='805', iid='169', r_ui=4.0, est=4.450732689121068, details={'was_impossible': False}),
#  Prediction(uid='59', iid='1021', r_ui=4.0, est=3.7675880529397126, details={'was_impossible': False}),
#  Prediction(uid='130', iid='330', r_ui=4.0, est=3.2195047310273224, details={'was_impossible': False}),
#  Prediction(uid='342', iid='249', r_ui=3.0, est=3.0585598216352405, details={'was_impossible': False}),
#  Prediction(uid='543', iid='947', r_ui=4.0, est=3.2836570598455985, details={'was_impossible': False}),
#  Prediction(uid='401', iid='473', r_ui=1.0, est=2.3642339253033473, details={'was_impossible': False}),
#  Prediction(uid='214', iid='856', r_ui=4.0, est=4.143984369454238, details={'was_impossible': False}),
#  Prediction(uid='936', iid='995', r_ui=3.0, est=3.35153472304552, details={'was_impossible': False}),
#  Prediction(uid='472', iid='72', r_ui=5.0, est=4.19920150566964, details={'was_impossible': False}),
#  Prediction(uid='268', iid='735', r_ui=3.0, est=3.7644256653033192, details={'was_impossible': False}),
#  Prediction(uid='366', iid='17', r_ui=5.0, est=4.049882239218969, details={'was_impossible': False}),
#  Prediction(uid='328', iid='752', r_ui=2.0, est=3.412206247118652, details={'was_impossible': False}),
#  Prediction(uid='6', iid='435', r_ui=4.0, est=3.7831978782488345, details={'was_impossible': False}),
#  Prediction(uid='815', iid='229', r_ui=3.0, est=3.324308408073408, details={'was_impossible': False}),
#  Prediction(uid='135', iid='943', r_ui=3.0, est=3.5560301159371486, details={'was_impossible': False}),
#  Prediction(uid='606', iid='827', r_ui=3.0, est=3.047293029653442, details={'was_impossible': False}),
#  Prediction(uid='268', iid='399', r_ui=3.0, est=2.8976136038878644, details={'was_impossible': False}),
#  Prediction(uid='188', iid='54', r_ui=4.0, est=3.3547290913527292, details={'was_impossible': False}),
#  Prediction(uid='191', iid='754', r_ui=3.0, est=3.2828343181883213, details={'was_impossible': False}),
#  Prediction(uid='189', iid='483', r_ui=5.0, est=4.769760140576366, details={'was_impossible': False}),
#  Prediction(uid='825', iid='12', r_ui=5.0, est=4.3332206498964085, details={'was_impossible': False}),
#  Prediction(uid='250', iid='331', r_ui=3.0, est=3.8056806248831028, details={'was_impossible': False}),
#  Prediction(uid='621', iid='417', r_ui=3.0, est=3.160962655107939, details={'was_impossible': False}),
#  Prediction(uid='542', iid='627', r_ui=3.0, est=3.2487718231580867, details={'was_impossible': False}),
#  Prediction(uid='683', iid='271', r_ui=3.0, est=3.046852552790586, details={'was_impossible': False}),
#  Prediction(uid='249', iid='125', r_ui=3.0, est=3.966878596688489, details={'was_impossible': False}),
#  Prediction(uid='922', iid='217', r_ui=3.0, est=3.0148849915840157, details={'was_impossible': False}),
#  Prediction(uid='72', iid='1110', r_ui=3.0, est=2.9661784585490514, details={'was_impossible': False}),
#  Prediction(uid='2', iid='314', r_ui=1.0, est=3.0087012504802533, details={'was_impossible': False}),
#  Prediction(uid='379', iid='712', r_ui=3.0, est=3.5915775114593176, details={'was_impossible': False}),
#  Prediction(uid='798', iid='95', r_ui=5.0, est=3.7556678977247406, details={'was_impossible': False}),
#  Prediction(uid='59', iid='926', r_ui=1.0, est=2.9363783895619413, details={'was_impossible': False}),
#  Prediction(uid='716', iid='209', r_ui=3.0, est=3.8604883239657273, details={'was_impossible': False}),
#  Prediction(uid='896', iid='77', r_ui=4.0, est=3.068768188047621, details={'was_impossible': False}),
#  Prediction(uid='51', iid='173', r_ui=5.0, est=3.4033408407967243, details={'was_impossible': False}),
#  Prediction(uid='708', iid='546', r_ui=3.0, est=3.2759290650520403, details={'was_impossible': False}),
#  Prediction(uid='49', iid='12', r_ui=4.0, est=3.543790120584235, details={'was_impossible': False}),
#  Prediction(uid='13', iid='49', r_ui=4.0, est=3.1825460368866594, details={'was_impossible': False}),
#  Prediction(uid='234', iid='54', r_ui=2.0, est=2.574664504683361, details={'was_impossible': False}),
#  Prediction(uid='82', iid='194', r_ui=4.0, est=3.6941191509847404, details={'was_impossible': False}),
#  Prediction(uid='763', iid='50', r_ui=4.0, est=4.180406631536103, details={'was_impossible': False}),
#  Prediction(uid='75', iid='1', r_ui=4.0, est=3.748111270612163, details={'was_impossible': False}),
#  Prediction(uid='472', iid='1110', r_ui=5.0, est=3.677852046629098, details={'was_impossible': False}),
#  Prediction(uid='537', iid='87', r_ui=3.0, est=3.456745707277418, details={'was_impossible': False}),
#  Prediction(uid='756', iid='860', r_ui=1.0, est=2.7716076883029386, details={'was_impossible': False}),
#  Prediction(uid='507', iid='1237', r_ui=5.0, est=4.909500003086787, details={'was_impossible': False}),
#  Prediction(uid='393', iid='62', r_ui=4.0, est=3.5452197495144353, details={'was_impossible': False}),
#  Prediction(uid='854', iid='528', r_ui=4.0, est=4.022366591576054, details={'was_impossible': False}),
#  Prediction(uid='90', iid='966', r_ui=5.0, est=4.347715688951938, details={'was_impossible': False}),
#  Prediction(uid='791', iid='306', r_ui=5.0, est=3.945788614727898, details={'was_impossible': False}),
#  Prediction(uid='114', iid='357', r_ui=4.0, est=4.1233607509671675, details={'was_impossible': False}),
#  Prediction(uid='343', iid='67', r_ui=3.0, est=3.461781585439926, details={'was_impossible': False}),
#  Prediction(uid='805', iid='769', r_ui=2.0, est=2.234906074059485, details={'was_impossible': False}),
#  Prediction(uid='279', iid='229', r_ui=4.0, est=2.9294682371092167, details={'was_impossible': False}),
#  Prediction(uid='60', iid='423', r_ui=4.0, est=4.396460060204864, details={'was_impossible': False}),
#  Prediction(uid='380', iid='956', r_ui=4.0, est=3.245744336486886, details={'was_impossible': False}),
#  Prediction(uid='16', iid='705', r_ui=5.0, est=4.561051852362359, details={'was_impossible': False}),
#  Prediction(uid='94', iid='1188', r_ui=3.0, est=3.060553620744439, details={'was_impossible': False}),
#  Prediction(uid='7', iid='584', r_ui=4.0, est=3.647860815826133, details={'was_impossible': False}),
#  Prediction(uid='486', iid='275', r_ui=4.0, est=3.826014215046404, details={'was_impossible': False}),
#  Prediction(uid='26', iid='322', r_ui=3.0, est=2.3929584925376433, details={'was_impossible': False}),
#  Prediction(uid='474', iid='697', r_ui=4.0, est=3.6589185277184098, details={'was_impossible': False}),
#  Prediction(uid='715', iid='156', r_ui=4.0, est=4.0015407472306155, details={'was_impossible': False}),
#  Prediction(uid='362', iid='748', r_ui=1.0, est=3.2928098387554443, details={'was_impossible': False}),
#  Prediction(uid='25', iid='7', r_ui=4.0, est=4.157781854172479, details={'was_impossible': False}),
#  Prediction(uid='394', iid='232', r_ui=4.0, est=3.716552281254927, details={'was_impossible': False}),
#  Prediction(uid='884', iid='640', r_ui=1.0, est=3.353816967812597, details={'was_impossible': False}),
#  Prediction(uid='735', iid='237', r_ui=4.0, est=3.2536380508653813, details={'was_impossible': False}),
#  Prediction(uid='399', iid='722', r_ui=2.0, est=2.323517516219538, details={'was_impossible': False}),
#  Prediction(uid='553', iid='484', r_ui=5.0, est=4.243405677929395, details={'was_impossible': False}),
#  Prediction(uid='668', iid='289', r_ui=2.0, est=2.835029131118472, details={'was_impossible': False}),
#  Prediction(uid='747', iid='498', r_ui=5.0, est=4.498803735333563, details={'was_impossible': False}),
#  Prediction(uid='160', iid='832', r_ui=1.0, est=3.081150638712508, details={'was_impossible': False}),
#  Prediction(uid='292', iid='276', r_ui=5.0, est=4.000549048577907, details={'was_impossible': False}),
#  Prediction(uid='712', iid='174', r_ui=5.0, est=4.509479734801948, details={'was_impossible': False}),
#  Prediction(uid='715', iid='68', r_ui=4.0, est=3.6073198719932953, details={'was_impossible': False}),
#  Prediction(uid='496', iid='607', r_ui=3.0, est=3.543241614825924, details={'was_impossible': False}),
#  Prediction(uid='82', iid='483', r_ui=5.0, est=4.028673064486157, details={'was_impossible': False}),
#  Prediction(uid='435', iid='431', r_ui=3.0, est=3.7126137986061982, details={'was_impossible': False}),
#  Prediction(uid='49', iid='594', r_ui=3.0, est=2.57996347755936, details={'was_impossible': False}),
#  Prediction(uid='334', iid='549', r_ui=4.0, est=3.856980535439372, details={'was_impossible': False}),
#  Prediction(uid='922', iid='455', r_ui=4.0, est=3.5195632573919937, details={'was_impossible': False}),
#  Prediction(uid='450', iid='451', r_ui=4.0, est=3.3557219486730476, details={'was_impossible': False}),
#  Prediction(uid='43', iid='235', r_ui=3.0, est=2.5530487721528083, details={'was_impossible': False}),
#  Prediction(uid='916', iid='256', r_ui=3.0, est=3.459327966360401, details={'was_impossible': False}),
#  Prediction(uid='568', iid='504', r_ui=3.0, est=3.1152515975213513, details={'was_impossible': False}),
#  Prediction(uid='587', iid='1624', r_ui=2.0, est=3.2935870644669216, details={'was_impossible': False}),
#  Prediction(uid='184', iid='191', r_ui=4.0, est=4.227136457123536, details={'was_impossible': False}),
#  Prediction(uid='328', iid='215', r_ui=3.0, est=3.4422764695290926, details={'was_impossible': False}),
#  Prediction(uid='114', iid='522', r_ui=5.0, est=3.5040411368370226, details={'was_impossible': False}),
#  Prediction(uid='298', iid='514', r_ui=4.0, est=4.487091701300849, details={'was_impossible': False}),
#  Prediction(uid='291', iid='128', r_ui=4.0, est=4.102572255715907, details={'was_impossible': False}),
#  Prediction(uid='149', iid='338', r_ui=2.0, est=2.1998007755753166, details={'was_impossible': False}),
#  Prediction(uid='5', iid='390', r_ui=5.0, est=3.0059842627696884, details={'was_impossible': False}),
#  Prediction(uid='157', iid='50', r_ui=4.0, est=4.674014463928371, details={'was_impossible': False}),
#  Prediction(uid='642', iid='581', r_ui=2.0, est=3.513994303624835, details={'was_impossible': False}),
#  Prediction(uid='559', iid='55', r_ui=4.0, est=3.4669974381782516, details={'was_impossible': False}),
#  Prediction(uid='270', iid='672', r_ui=5.0, est=3.676763780295972, details={'was_impossible': False}),
#  Prediction(uid='458', iid='199', r_ui=4.0, est=4.389476068918746, details={'was_impossible': False}),
#  Prediction(uid='327', iid='48', r_ui=4.0, est=3.7958211296220195, details={'was_impossible': False}),
#  Prediction(uid='215', iid='229', r_ui=3.0, est=3.039524889775188, details={'was_impossible': False}),
#  Prediction(uid='804', iid='172', r_ui=4.0, est=4.524343416800311, details={'was_impossible': False}),
#  Prediction(uid='758', iid='1019', r_ui=4.0, est=4.392442123400421, details={'was_impossible': False}),
#  Prediction(uid='901', iid='63', r_ui=5.0, est=3.460157782991866, details={'was_impossible': False}),
#  Prediction(uid='551', iid='926', r_ui=2.0, est=3.408329559666022, details={'was_impossible': False}),
#  Prediction(uid='663', iid='876', r_ui=3.0, est=2.785506340942477, details={'was_impossible': False}),
#  Prediction(uid='830', iid='554', r_ui=5.0, est=2.4835260733881155, details={'was_impossible': False}),
#  Prediction(uid='271', iid='498', r_ui=5.0, est=4.185235583914449, details={'was_impossible': False}),
#  Prediction(uid='342', iid='15', r_ui=3.0, est=3.392643078644025, details={'was_impossible': False}),
#  Prediction(uid='403', iid='477', r_ui=4.0, est=3.6846752978033597, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1550', r_ui=3.0, est=2.168648390151812, details={'was_impossible': False}),
#  Prediction(uid='393', iid='932', r_ui=3.0, est=2.8071493630105038, details={'was_impossible': False}),
#  Prediction(uid='189', iid='180', r_ui=5.0, est=4.1728472119614946, details={'was_impossible': False}),
#  Prediction(uid='472', iid='401', r_ui=4.0, est=3.922805179865725, details={'was_impossible': False}),
#  Prediction(uid='472', iid='392', r_ui=4.0, est=4.178431059317338, details={'was_impossible': False}),
#  Prediction(uid='10', iid='200', r_ui=5.0, est=4.201932146481643, details={'was_impossible': False}),
#  Prediction(uid='359', iid='295', r_ui=3.0, est=3.8276740612346654, details={'was_impossible': False}),
#  Prediction(uid='215', iid='480', r_ui=5.0, est=4.2621369758979055, details={'was_impossible': False}),
#  Prediction(uid='505', iid='187', r_ui=1.0, est=3.4514706520103617, details={'was_impossible': False}),
#  Prediction(uid='643', iid='153', r_ui=4.0, est=4.062517629072503, details={'was_impossible': False}),
#  Prediction(uid='506', iid='248', r_ui=2.0, est=3.4886245679173737, details={'was_impossible': False}),
#  Prediction(uid='601', iid='436', r_ui=4.0, est=3.2475452591038247, details={'was_impossible': False}),
#  Prediction(uid='64', iid='258', r_ui=3.0, est=4.018378094721535, details={'was_impossible': False}),
#  Prediction(uid='218', iid='648', r_ui=4.0, est=3.74316963024637, details={'was_impossible': False}),
#  Prediction(uid='318', iid='697', r_ui=5.0, est=3.5471949314666036, details={'was_impossible': False}),
#  Prediction(uid='308', iid='484', r_ui=3.0, est=4.51446099117441, details={'was_impossible': False}),
#  Prediction(uid='453', iid='697', r_ui=4.0, est=2.6394289121351577, details={'was_impossible': False}),
#  Prediction(uid='731', iid='320', r_ui=1.0, est=3.333812813529052, details={'was_impossible': False}),
#  Prediction(uid='756', iid='398', r_ui=3.0, est=2.2776694345486628, details={'was_impossible': False}),
#  Prediction(uid='700', iid='202', r_ui=3.0, est=3.5504003184329584, details={'was_impossible': False}),
#  Prediction(uid='532', iid='496', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='554', iid='238', r_ui=3.0, est=3.8315334140329202, details={'was_impossible': False}),
#  Prediction(uid='557', iid='166', r_ui=4.0, est=4.250760426193871, details={'was_impossible': False}),
#  Prediction(uid='72', iid='1', r_ui=4.0, est=4.210920275429658, details={'was_impossible': False}),
#  Prediction(uid='727', iid='771', r_ui=3.0, est=2.5252031205860628, details={'was_impossible': False}),
#  Prediction(uid='712', iid='949', r_ui=4.0, est=3.6181194329085034, details={'was_impossible': False}),
#  Prediction(uid='130', iid='173', r_ui=3.0, est=4.820293969741997, details={'was_impossible': False}),
#  Prediction(uid='454', iid='95', r_ui=2.0, est=2.987345525038748, details={'was_impossible': False}),
#  Prediction(uid='13', iid='678', r_ui=3.0, est=2.0500698234576347, details={'was_impossible': False}),
#  Prediction(uid='894', iid='147', r_ui=3.0, est=3.4067847636461877, details={'was_impossible': False}),
#  Prediction(uid='82', iid='133', r_ui=4.0, est=3.494278242594172, details={'was_impossible': False}),
#  Prediction(uid='181', iid='289', r_ui=4.0, est=1.3034479202162537, details={'was_impossible': False}),
#  Prediction(uid='334', iid='4', r_ui=3.0, est=3.533610533454485, details={'was_impossible': False}),
#  Prediction(uid='298', iid='144', r_ui=4.0, est=4.380037365479766, details={'was_impossible': False}),
#  Prediction(uid='711', iid='724', r_ui=5.0, est=3.946179355391803, details={'was_impossible': False}),
#  Prediction(uid='301', iid='56', r_ui=4.0, est=4.375328526124856, details={'was_impossible': False}),
#  Prediction(uid='134', iid='1', r_ui=5.0, est=4.154443853664839, details={'was_impossible': False}),
#  Prediction(uid='890', iid='451', r_ui=2.0, est=3.7455022590965745, details={'was_impossible': False}),
#  Prediction(uid='630', iid='111', r_ui=5.0, est=3.4036279542914945, details={'was_impossible': False}),
#  Prediction(uid='782', iid='687', r_ui=2.0, est=1.7930677958387287, details={'was_impossible': False}),
#  Prediction(uid='922', iid='579', r_ui=3.0, est=2.889707076927968, details={'was_impossible': False}),
#  Prediction(uid='263', iid='199', r_ui=5.0, est=4.662102839754736, details={'was_impossible': False}),
#  Prediction(uid='796', iid='1297', r_ui=2.0, est=3.0249139917786967, details={'was_impossible': False}),
#  Prediction(uid='407', iid='230', r_ui=4.0, est=3.2187145446727605, details={'was_impossible': False}),
#  Prediction(uid='200', iid='227', r_ui=5.0, est=4.1732387873742285, details={'was_impossible': False}),
#  Prediction(uid='927', iid='385', r_ui=4.0, est=3.956571892653882, details={'was_impossible': False}),
#  Prediction(uid='92', iid='121', r_ui=5.0, est=3.284411767887524, details={'was_impossible': False}),
#  Prediction(uid='188', iid='162', r_ui=4.0, est=3.597105145592899, details={'was_impossible': False}),
#  Prediction(uid='712', iid='143', r_ui=5.0, est=4.36863496138484, details={'was_impossible': False}),
#  Prediction(uid='197', iid='50', r_ui=5.0, est=4.537059932855613, details={'was_impossible': False}),
#  Prediction(uid='823', iid='154', r_ui=5.0, est=4.386012095044581, details={'was_impossible': False}),
#  Prediction(uid='868', iid='24', r_ui=2.0, est=3.1776340087164976, details={'was_impossible': False}),
#  Prediction(uid='119', iid='25', r_ui=5.0, est=3.84760408088141, details={'was_impossible': False}),
#  Prediction(uid='43', iid='272', r_ui=5.0, est=4.4598055264273615, details={'was_impossible': False}),
#  Prediction(uid='450', iid='489', r_ui=4.0, est=4.394406648348963, details={'was_impossible': False}),
#  Prediction(uid='328', iid='199', r_ui=4.0, est=4.263517798776615, details={'was_impossible': False}),
#  Prediction(uid='113', iid='329', r_ui=3.0, est=3.6594737361545766, details={'was_impossible': False}),
#  Prediction(uid='267', iid='576', r_ui=3.0, est=3.16006166445292, details={'was_impossible': False}),
#  Prediction(uid='620', iid='313', r_ui=5.0, est=4.435426834710802, details={'was_impossible': False}),
#  Prediction(uid='269', iid='132', r_ui=5.0, est=3.951540732424006, details={'was_impossible': False}),
#  Prediction(uid='693', iid='191', r_ui=2.0, est=3.6820748568667088, details={'was_impossible': False}),
#  Prediction(uid='169', iid='134', r_ui=5.0, est=4.28111999066319, details={'was_impossible': False}),
#  Prediction(uid='95', iid='843', r_ui=4.0, est=2.720224190055379, details={'was_impossible': False}),
#  Prediction(uid='378', iid='160', r_ui=2.0, est=3.1751523891798814, details={'was_impossible': False}),
#  Prediction(uid='880', iid='161', r_ui=2.0, est=3.572125853244131, details={'was_impossible': False}),
#  Prediction(uid='645', iid='61', r_ui=5.0, est=4.176954364792091, details={'was_impossible': False}),
#  Prediction(uid='361', iid='213', r_ui=5.0, est=4.08646816584959, details={'was_impossible': False}),
#  Prediction(uid='353', iid='898', r_ui=2.0, est=3.29038951978926, details={'was_impossible': False}),
#  Prediction(uid='286', iid='455', r_ui=1.0, est=3.127346303761224, details={'was_impossible': False}),
#  Prediction(uid='565', iid='52', r_ui=5.0, est=4.461496414787616, details={'was_impossible': False}),
#  Prediction(uid='495', iid='391', r_ui=3.0, est=3.8513601973080083, details={'was_impossible': False}),
#  Prediction(uid='716', iid='504', r_ui=5.0, est=3.9665768181015943, details={'was_impossible': False}),
#  Prediction(uid='471', iid='969', r_ui=2.0, est=3.184941798921322, details={'was_impossible': False}),
#  Prediction(uid='940', iid='89', r_ui=4.0, est=3.6128448871037318, details={'was_impossible': False}),
#  Prediction(uid='877', iid='549', r_ui=4.0, est=3.875092523463281, details={'was_impossible': False}),
#  Prediction(uid='903', iid='655', r_ui=5.0, est=3.889214228020053, details={'was_impossible': False}),
#  Prediction(uid='346', iid='1210', r_ui=3.0, est=2.5098759473213503, details={'was_impossible': False}),
#  Prediction(uid='303', iid='5', r_ui=2.0, est=3.283040416803479, details={'was_impossible': False}),
#  Prediction(uid='332', iid='123', r_ui=4.0, est=4.166813079765706, details={'was_impossible': False}),
#  Prediction(uid='825', iid='595', r_ui=3.0, est=3.285078493677994, details={'was_impossible': False}),
#  Prediction(uid='616', iid='328', r_ui=3.0, est=3.8157666425260683, details={'was_impossible': False}),
#  Prediction(uid='417', iid='99', r_ui=4.0, est=3.641514934244407, details={'was_impossible': False}),
#  Prediction(uid='548', iid='898', r_ui=1.0, est=3.1670889930407675, details={'was_impossible': False}),
#  Prediction(uid='727', iid='282', r_ui=4.0, est=3.2849629180561655, details={'was_impossible': False}),
#  Prediction(uid='630', iid='640', r_ui=1.0, est=3.1410885335985577, details={'was_impossible': False}),
#  Prediction(uid='292', iid='653', r_ui=4.0, est=4.280219425744984, details={'was_impossible': False}),
#  Prediction(uid='497', iid='163', r_ui=2.0, est=3.514303922233381, details={'was_impossible': False}),
#  Prediction(uid='23', iid='181', r_ui=4.0, est=3.49161906131673, details={'was_impossible': False}),
#  Prediction(uid='178', iid='222', r_ui=4.0, est=4.037008202128701, details={'was_impossible': False}),
#  Prediction(uid='645', iid='709', r_ui=3.0, est=4.310874062894617, details={'was_impossible': False}),
#  Prediction(uid='805', iid='806', r_ui=4.0, est=3.163066931726643, details={'was_impossible': False}),
#  Prediction(uid='275', iid='142', r_ui=2.0, est=2.564997123031221, details={'was_impossible': False}),
#  Prediction(uid='648', iid='4', r_ui=1.0, est=3.3871255783793024, details={'was_impossible': False}),
#  Prediction(uid='18', iid='89', r_ui=3.0, est=4.36213489210102, details={'was_impossible': False}),
#  Prediction(uid='795', iid='1095', r_ui=3.0, est=2.388128914622355, details={'was_impossible': False}),
#  Prediction(uid='497', iid='452', r_ui=2.0, est=2.4709948070710643, details={'was_impossible': False}),
#  Prediction(uid='92', iid='278', r_ui=3.0, est=2.7731324908252057, details={'was_impossible': False}),
#  Prediction(uid='505', iid='313', r_ui=5.0, est=3.773788722296412, details={'was_impossible': False}),
#  Prediction(uid='174', iid='471', r_ui=5.0, est=4.13034215253707, details={'was_impossible': False}),
#  Prediction(uid='59', iid='273', r_ui=2.0, est=4.108915074500227, details={'was_impossible': False}),
#  Prediction(uid='648', iid='205', r_ui=3.0, est=3.7190741396261457, details={'was_impossible': False}),
#  Prediction(uid='327', iid='249', r_ui=2.0, est=2.9590546932442683, details={'was_impossible': False}),
#  Prediction(uid='751', iid='204', r_ui=4.0, est=3.567284981259584, details={'was_impossible': False}),
#  Prediction(uid='447', iid='411', r_ui=2.0, est=3.1142744911497022, details={'was_impossible': False}),
#  Prediction(uid='648', iid='797', r_ui=3.0, est=3.0096318148915615, details={'was_impossible': False}),
#  Prediction(uid='666', iid='122', r_ui=2.0, est=2.2127633310381825, details={'was_impossible': False}),
#  Prediction(uid='660', iid='173', r_ui=5.0, est=3.30881362008376, details={'was_impossible': False}),
#  Prediction(uid='537', iid='730', r_ui=3.0, est=2.9333766360338895, details={'was_impossible': False}),
#  Prediction(uid='896', iid='23', r_ui=2.0, est=3.796774479228309, details={'was_impossible': False}),
#  Prediction(uid='174', iid='402', r_ui=5.0, est=3.499174803185111, details={'was_impossible': False}),
#  Prediction(uid='520', iid='300', r_ui=4.0, est=3.510495621182338, details={'was_impossible': False}),
#  Prediction(uid='634', iid='294', r_ui=4.0, est=3.324192456581048, details={'was_impossible': False}),
#  Prediction(uid='223', iid='248', r_ui=1.0, est=3.298852895391533, details={'was_impossible': False}),
#  Prediction(uid='451', iid='1392', r_ui=1.0, est=2.7538799633108337, details={'was_impossible': False}),
#  Prediction(uid='301', iid='357', r_ui=5.0, est=4.073263115829635, details={'was_impossible': False}),
#  Prediction(uid='25', iid='837', r_ui=4.0, est=4.26264681945235, details={'was_impossible': False}),
#  Prediction(uid='401', iid='174', r_ui=4.0, est=3.6510134445672455, details={'was_impossible': False}),
#  Prediction(uid='629', iid='886', r_ui=3.0, est=3.395241616502662, details={'was_impossible': False}),
#  Prediction(uid='49', iid='403', r_ui=3.0, est=2.507342279116799, details={'was_impossible': False}),
#  Prediction(uid='793', iid='508', r_ui=4.0, est=3.7587119851073045, details={'was_impossible': False}),
#  Prediction(uid='327', iid='527', r_ui=4.0, est=3.670373553933554, details={'was_impossible': False}),
#  Prediction(uid='57', iid='717', r_ui=4.0, est=2.7360826398522518, details={'was_impossible': False}),
#  Prediction(uid='116', iid='346', r_ui=4.0, est=3.0932373001335653, details={'was_impossible': False}),
#  Prediction(uid='18', iid='189', r_ui=5.0, est=4.1992290801589185, details={'was_impossible': False}),
#  Prediction(uid='129', iid='327', r_ui=3.0, est=2.866111173549968, details={'was_impossible': False}),
#  Prediction(uid='255', iid='546', r_ui=3.0, est=1.876086452504301, details={'was_impossible': False}),
#  Prediction(uid='486', iid='181', r_ui=4.0, est=3.7579809672519806, details={'was_impossible': False}),
#  Prediction(uid='286', iid='167', r_ui=5.0, est=3.2791080806547384, details={'was_impossible': False}),
#  Prediction(uid='641', iid='83', r_ui=4.0, est=4.5290346431715856, details={'was_impossible': False}),
#  Prediction(uid='752', iid='1024', r_ui=3.0, est=3.4275536238648137, details={'was_impossible': False}),
#  Prediction(uid='10', iid='502', r_ui=4.0, est=4.266602826235125, details={'was_impossible': False}),
#  Prediction(uid='557', iid='875', r_ui=4.0, est=2.927833462031394, details={'was_impossible': False}),
#  Prediction(uid='13', iid='42', r_ui=4.0, est=2.7480986105498464, details={'was_impossible': False}),
#  Prediction(uid='74', iid='245', r_ui=3.0, est=3.166885063421212, details={'was_impossible': False}),
#  Prediction(uid='308', iid='214', r_ui=2.0, est=3.722419766692895, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1025', r_ui=2.0, est=2.7651554832128467, details={'was_impossible': False}),
#  Prediction(uid='269', iid='96', r_ui=1.0, est=2.616958752569586, details={'was_impossible': False}),
#  Prediction(uid='537', iid='171', r_ui=3.0, est=3.404346986069057, details={'was_impossible': False}),
#  Prediction(uid='538', iid='527', r_ui=3.0, est=4.16753705996328, details={'was_impossible': False}),
#  Prediction(uid='683', iid='880', r_ui=3.0, est=2.870237916743811, details={'was_impossible': False}),
#  Prediction(uid='234', iid='956', r_ui=3.0, est=2.9131896132954966, details={'was_impossible': False}),
#  Prediction(uid='361', iid='657', r_ui=5.0, est=4.431410922500464, details={'was_impossible': False}),
#  Prediction(uid='884', iid='70', r_ui=4.0, est=3.8439229505709602, details={'was_impossible': False}),
#  Prediction(uid='160', iid='79', r_ui=4.0, est=3.8704770897798597, details={'was_impossible': False}),
#  Prediction(uid='308', iid='501', r_ui=4.0, est=3.537077546065774, details={'was_impossible': False}),
#  Prediction(uid='301', iid='197', r_ui=5.0, est=4.030969482115843, details={'was_impossible': False}),
#  Prediction(uid='533', iid='1282', r_ui=3.0, est=2.8946564367184533, details={'was_impossible': False}),
#  Prediction(uid='13', iid='420', r_ui=4.0, est=3.512056864946299, details={'was_impossible': False}),
#  Prediction(uid='276', iid='228', r_ui=4.0, est=3.7358922442339555, details={'was_impossible': False}),
#  Prediction(uid='234', iid='656', r_ui=4.0, est=3.7159763300796627, details={'was_impossible': False}),
#  Prediction(uid='822', iid='91', r_ui=3.0, est=3.6489890565791456, details={'was_impossible': False}),
#  Prediction(uid='244', iid='290', r_ui=3.0, est=3.1765204662688418, details={'was_impossible': False}),
#  Prediction(uid='276', iid='571', r_ui=2.0, est=2.7319542008351494, details={'was_impossible': False}),
#  Prediction(uid='618', iid='815', r_ui=4.0, est=2.6945846487193146, details={'was_impossible': False}),
#  Prediction(uid='429', iid='87', r_ui=3.0, est=3.739437060863557, details={'was_impossible': False}),
#  Prediction(uid='43', iid='283', r_ui=2.0, est=3.8141404742674103, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1439', r_ui=1.0, est=1.6352263770790747, details={'was_impossible': False}),
#  Prediction(uid='234', iid='166', r_ui=5.0, est=3.313608254057941, details={'was_impossible': False}),
#  Prediction(uid='92', iid='408', r_ui=4.0, est=4.397362375166726, details={'was_impossible': False}),
#  Prediction(uid='314', iid='71', r_ui=5.0, est=4.2228129512207095, details={'was_impossible': False}),
#  Prediction(uid='617', iid='17', r_ui=1.0, est=2.7710988102075924, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1348', r_ui=1.0, est=1.7517635751836815, details={'was_impossible': False}),
#  Prediction(uid='256', iid='283', r_ui=3.0, est=4.30643163633478, details={'was_impossible': False}),
#  Prediction(uid='295', iid='843', r_ui=4.0, est=3.6476039394925777, details={'was_impossible': False}),
#  Prediction(uid='833', iid='614', r_ui=2.0, est=3.305259379621879, details={'was_impossible': False}),
#  Prediction(uid='854', iid='846', r_ui=3.0, est=2.5739566501965916, details={'was_impossible': False}),
#  Prediction(uid='206', iid='1430', r_ui=1.0, est=2.3409810432595988, details={'was_impossible': False}),
#  Prediction(uid='119', iid='194', r_ui=5.0, est=4.719362680130634, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1045', r_ui=3.0, est=2.9666832435648662, details={'was_impossible': False}),
#  Prediction(uid='85', iid='506', r_ui=4.0, est=3.7683920825364616, details={'was_impossible': False}),
#  Prediction(uid='316', iid='127', r_ui=2.0, est=3.4975774376628004, details={'was_impossible': False}),
#  Prediction(uid='316', iid='323', r_ui=1.0, est=2.4761837518881253, details={'was_impossible': False}),
#  Prediction(uid='567', iid='212', r_ui=2.0, est=4.0259715841840205, details={'was_impossible': False}),
#  Prediction(uid='435', iid='635', r_ui=3.0, est=2.8963580262972766, details={'was_impossible': False}),
#  Prediction(uid='823', iid='135', r_ui=4.0, est=4.38282786468362, details={'was_impossible': False}),
#  Prediction(uid='78', iid='298', r_ui=3.0, est=3.738442627900848, details={'was_impossible': False}),
#  Prediction(uid='297', iid='195', r_ui=1.0, est=3.3852539910203148, details={'was_impossible': False}),
#  Prediction(uid='560', iid='1073', r_ui=3.0, est=3.6472921187537852, details={'was_impossible': False}),
#  Prediction(uid='521', iid='184', r_ui=4.0, est=3.194135239088971, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1422', r_ui=1.0, est=1.8592910682950676, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1041', r_ui=4.0, est=3.3785800078676607, details={'was_impossible': False}),
#  Prediction(uid='880', iid='356', r_ui=4.0, est=3.6441829246753463, details={'was_impossible': False}),
#  Prediction(uid='537', iid='689', r_ui=1.0, est=2.32543384113956, details={'was_impossible': False}),
#  Prediction(uid='326', iid='8', r_ui=4.0, est=3.0733169578089123, details={'was_impossible': False}),
#  Prediction(uid='268', iid='380', r_ui=2.0, est=2.6641995248246184, details={'was_impossible': False}),
#  Prediction(uid='896', iid='525', r_ui=5.0, est=3.4978376033278575, details={'was_impossible': False}),
#  Prediction(uid='919', iid='1048', r_ui=3.0, est=3.064175009134082, details={'was_impossible': False}),
#  Prediction(uid='279', iid='10', r_ui=4.0, est=4.259402429440497, details={'was_impossible': False}),
#  Prediction(uid='766', iid='179', r_ui=4.0, est=3.6970446021028316, details={'was_impossible': False}),
#  Prediction(uid='318', iid='628', r_ui=4.0, est=3.371295152598097, details={'was_impossible': False}),
#  Prediction(uid='276', iid='751', r_ui=4.0, est=3.9289354657897766, details={'was_impossible': False}),
#  Prediction(uid='369', iid='948', r_ui=2.0, est=2.743616278025658, details={'was_impossible': False}),
#  Prediction(uid='698', iid='86', r_ui=2.0, est=2.9734060256430257, details={'was_impossible': False}),
#  Prediction(uid='222', iid='222', r_ui=4.0, est=3.697540263053798, details={'was_impossible': False}),
#  Prediction(uid='936', iid='756', r_ui=4.0, est=3.2985909785918412, details={'was_impossible': False}),
#  Prediction(uid='831', iid='307', r_ui=2.0, est=3.400698512750733, details={'was_impossible': False}),
#  Prediction(uid='109', iid='72', r_ui=5.0, est=3.451254436917195, details={'was_impossible': False}),
#  Prediction(uid='130', iid='271', r_ui=5.0, est=3.542768305213264, details={'was_impossible': False}),
#  Prediction(uid='745', iid='425', r_ui=4.0, est=2.7344607012763165, details={'was_impossible': False}),
#  Prediction(uid='330', iid='58', r_ui=5.0, est=4.373962988599676, details={'was_impossible': False}),
#  Prediction(uid='535', iid='1124', r_ui=4.0, est=3.6870986233791343, details={'was_impossible': False}),
#  Prediction(uid='320', iid='774', r_ui=4.0, est=3.6411905287850055, details={'was_impossible': False}),
#  Prediction(uid='424', iid='288', r_ui=1.0, est=3.252295969535445, details={'was_impossible': False}),
#  Prediction(uid='16', iid='583', r_ui=4.0, est=3.1798668590707835, details={'was_impossible': False}),
#  Prediction(uid='128', iid='159', r_ui=4.0, est=3.2021627143333475, details={'was_impossible': False}),
#  Prediction(uid='739', iid='176', r_ui=1.0, est=3.964561880979426, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1160', r_ui=4.0, est=3.6209714286416217, details={'was_impossible': False}),
#  Prediction(uid='606', iid='138', r_ui=3.0, est=3.3235479400458496, details={'was_impossible': False}),
#  Prediction(uid='665', iid='687', r_ui=2.0, est=2.4362450565195686, details={'was_impossible': False}),
#  Prediction(uid='664', iid='53', r_ui=3.0, est=3.38529256613554, details={'was_impossible': False}),
#  Prediction(uid='476', iid='959', r_ui=3.0, est=3.2941743332169935, details={'was_impossible': False}),
#  Prediction(uid='758', iid='898', r_ui=3.0, est=3.349881187384363, details={'was_impossible': False}),
#  Prediction(uid='851', iid='979', r_ui=3.0, est=3.6261460262586915, details={'was_impossible': False}),
#  Prediction(uid='263', iid='82', r_ui=4.0, est=3.8747220133525375, details={'was_impossible': False}),
#  Prediction(uid='608', iid='190', r_ui=4.0, est=4.148918735622545, details={'was_impossible': False}),
#  Prediction(uid='551', iid='84', r_ui=1.0, est=3.0521699348638704, details={'was_impossible': False}),
# ...
#  Prediction(uid='534', iid='455', r_ui=5.0, est=4.224577516859274, details={'was_impossible': False}),
#  Prediction(uid='94', iid='824', r_ui=4.0, est=2.859303296249081, details={'was_impossible': False}),
#  Prediction(uid='804', iid='231', r_ui=4.0, est=2.8509282387627892, details={'was_impossible': False}),
#  Prediction(uid='270', iid='164', r_ui=5.0, est=4.456142024685497, details={'was_impossible': False}),
#  Prediction(uid='286', iid='250', r_ui=4.0, est=3.4536892412676936, details={'was_impossible': False}),
#  Prediction(uid='342', iid='236', r_ui=3.0, est=3.434301279113752, details={'was_impossible': False}),
#  Prediction(uid='44', iid='82', r_ui=4.0, est=3.8732616858846134, details={'was_impossible': False}),
#  Prediction(uid='467', iid='455', r_ui=3.0, est=3.6126265921835388, details={'was_impossible': False}),
#  Prediction(uid='871', iid='147', r_ui=5.0, est=3.5219515452578687, details={'was_impossible': False}),
#  Prediction(uid='216', iid='274', r_ui=3.0, est=3.496751934836206, details={'was_impossible': False}),
#  Prediction(uid='749', iid='9', r_ui=3.0, est=4.168420894503461, details={'was_impossible': False}),
#  Prediction(uid='815', iid='523', r_ui=4.0, est=3.9470753458292953, details={'was_impossible': False}),
#  Prediction(uid='372', iid='79', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='301', iid='426', r_ui=4.0, est=2.933042932851065, details={'was_impossible': False}),
#  Prediction(uid='292', iid='320', r_ui=5.0, est=4.5644435516776545, details={'was_impossible': False}),
#  Prediction(uid='151', iid='356', r_ui=2.0, est=3.454672669038416, details={'was_impossible': False}),
#  Prediction(uid='244', iid='790', r_ui=4.0, est=3.1712931754396654, details={'was_impossible': False}),
#  Prediction(uid='815', iid='50', r_ui=5.0, est=4.614187479428141, details={'was_impossible': False}),
#  Prediction(uid='599', iid='535', r_ui=4.0, est=3.9109789906572012, details={'was_impossible': False}),
#  Prediction(uid='518', iid='14', r_ui=3.0, est=3.8648018758314215, details={'was_impossible': False}),
#  Prediction(uid='181', iid='978', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='686', iid='969', r_ui=5.0, est=4.430911904204706, details={'was_impossible': False}),
#  Prediction(uid='16', iid='504', r_ui=5.0, est=4.059410883445211, details={'was_impossible': False}),
#  Prediction(uid='43', iid='298', r_ui=4.0, est=3.6164546462507405, details={'was_impossible': False}),
#  Prediction(uid='505', iid='755', r_ui=3.0, est=3.2741250948931695, details={'was_impossible': False}),
#  Prediction(uid='104', iid='100', r_ui=4.0, est=3.5612838753458136, details={'was_impossible': False}),
#  Prediction(uid='336', iid='1496', r_ui=1.0, est=2.688553277772841, details={'was_impossible': False}),
#  Prediction(uid='95', iid='193', r_ui=3.0, est=3.8887850791672145, details={'was_impossible': False}),
#  Prediction(uid='519', iid='1434', r_ui=5.0, est=4.232658728334691, details={'was_impossible': False}),
#  Prediction(uid='592', iid='265', r_ui=4.0, est=4.198890727266993, details={'was_impossible': False}),
#  Prediction(uid='262', iid='790', r_ui=3.0, est=2.5673665692974987, details={'was_impossible': False}),
#  Prediction(uid='92', iid='684', r_ui=3.0, est=3.492299733800331, details={'was_impossible': False}),
#  Prediction(uid='844', iid='168', r_ui=4.0, est=3.6675230921560362, details={'was_impossible': False}),
#  Prediction(uid='903', iid='196', r_ui=4.0, est=3.917487577100357, details={'was_impossible': False}),
#  Prediction(uid='901', iid='94', r_ui=4.0, est=3.8554897244731716, details={'was_impossible': False}),
#  Prediction(uid='223', iid='866', r_ui=4.0, est=3.129436551136988, details={'was_impossible': False}),
#  Prediction(uid='101', iid='819', r_ui=1.0, est=2.4507362954340848, details={'was_impossible': False}),
#  Prediction(uid='378', iid='194', r_ui=4.0, est=4.024878609744154, details={'was_impossible': False}),
#  Prediction(uid='121', iid='315', r_ui=4.0, est=3.892694185059197, details={'was_impossible': False}),
#  Prediction(uid='804', iid='448', r_ui=3.0, est=3.872630805978375, details={'was_impossible': False}),
#  Prediction(uid='429', iid='170', r_ui=5.0, est=4.214296971412737, details={'was_impossible': False}),
#  Prediction(uid='90', iid='433', r_ui=3.0, est=3.9096554873239517, details={'was_impossible': False}),
#  Prediction(uid='102', iid='88', r_ui=3.0, est=2.857338725871022, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1471', r_ui=2.0, est=2.9995297232219156, details={'was_impossible': False}),
#  Prediction(uid='883', iid='707', r_ui=3.0, est=4.233210944549196, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1239', r_ui=1.0, est=2.9374923937472572, details={'was_impossible': False}),
#  Prediction(uid='864', iid='116', r_ui=4.0, est=4.067595629850376, details={'was_impossible': False}),
#  Prediction(uid='95', iid='510', r_ui=4.0, est=3.4616289566691236, details={'was_impossible': False}),
#  Prediction(uid='102', iid='684', r_ui=2.0, est=3.0086646604101563, details={'was_impossible': False}),
#  Prediction(uid='333', iid='186', r_ui=4.0, est=4.060491836710835, details={'was_impossible': False}),
#  Prediction(uid='495', iid='82', r_ui=5.0, est=4.779686621390002, details={'was_impossible': False}),
#  Prediction(uid='854', iid='493', r_ui=5.0, est=3.7680924327155054, details={'was_impossible': False}),
#  Prediction(uid='313', iid='164', r_ui=3.0, est=3.6860590774688906, details={'was_impossible': False}),
#  Prediction(uid='536', iid='679', r_ui=4.0, est=3.070159253171746, details={'was_impossible': False}),
#  Prediction(uid='181', iid='19', r_ui=1.0, est=2.0600435963407664, details={'was_impossible': False}),
#  Prediction(uid='185', iid='269', r_ui=5.0, est=3.8129195675597147, details={'was_impossible': False}),
#  Prediction(uid='314', iid='216', r_ui=3.0, est=4.227213597363119, details={'was_impossible': False}),
#  Prediction(uid='314', iid='623', r_ui=5.0, est=3.1611709399501544, details={'was_impossible': False}),
#  Prediction(uid='416', iid='357', r_ui=5.0, est=4.723508052821783, details={'was_impossible': False}),
#  Prediction(uid='180', iid='258', r_ui=5.0, est=4.22603225323686, details={'was_impossible': False}),
#  Prediction(uid='423', iid='898', r_ui=4.0, est=2.9021898347765824, details={'was_impossible': False}),
#  Prediction(uid='389', iid='997', r_ui=3.0, est=2.8720612885800625, details={'was_impossible': False}),
#  Prediction(uid='207', iid='476', r_ui=2.0, est=2.966345248508011, details={'was_impossible': False}),
#  Prediction(uid='18', iid='212', r_ui=5.0, est=3.783527590928433, details={'was_impossible': False}),
#  Prediction(uid='639', iid='661', r_ui=4.0, est=3.450032907080465, details={'was_impossible': False}),
#  Prediction(uid='737', iid='186', r_ui=5.0, est=3.678931521828367, details={'was_impossible': False}),
#  Prediction(uid='324', iid='14', r_ui=5.0, est=4.843137953725433, details={'was_impossible': False}),
#  Prediction(uid='825', iid='250', r_ui=5.0, est=3.6155550094054973, details={'was_impossible': False}),
#  Prediction(uid='332', iid='1047', r_ui=3.0, est=3.6917356618833903, details={'was_impossible': False}),
#  Prediction(uid='761', iid='457', r_ui=1.0, est=1.598669436897818, details={'was_impossible': False}),
#  Prediction(uid='219', iid='879', r_ui=4.0, est=3.310889132694567, details={'was_impossible': False}),
#  Prediction(uid='881', iid='1118', r_ui=3.0, est=3.3599842626064103, details={'was_impossible': False}),
#  Prediction(uid='149', iid='333', r_ui=1.0, est=3.1208613114192003, details={'was_impossible': False}),
#  Prediction(uid='327', iid='89', r_ui=4.0, est=3.371007953999746, details={'was_impossible': False}),
#  Prediction(uid='259', iid='1074', r_ui=3.0, est=3.249014275112875, details={'was_impossible': False}),
#  Prediction(uid='721', iid='1', r_ui=5.0, est=3.7574953781520275, details={'was_impossible': False}),
#  Prediction(uid='177', iid='527', r_ui=4.0, est=4.096813532268191, details={'was_impossible': False}),
#  Prediction(uid='897', iid='371', r_ui=2.0, est=3.9152727663201463, details={'was_impossible': False}),
#  Prediction(uid='378', iid='172', r_ui=4.0, est=4.221053568487428, details={'was_impossible': False}),
#  Prediction(uid='417', iid='17', r_ui=4.0, est=2.6256931016985305, details={'was_impossible': False}),
#  Prediction(uid='639', iid='1065', r_ui=1.0, est=2.9999302542893536, details={'was_impossible': False}),
#  Prediction(uid='393', iid='291', r_ui=4.0, est=3.5836033555411677, details={'was_impossible': False}),
#  Prediction(uid='269', iid='232', r_ui=1.0, est=2.473493517008354, details={'was_impossible': False}),
#  Prediction(uid='339', iid='126', r_ui=4.0, est=4.486820379826432, details={'was_impossible': False}),
#  Prediction(uid='370', iid='323', r_ui=2.0, est=2.925146712622744, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1049', r_ui=3.0, est=2.7637242794254235, details={'was_impossible': False}),
#  Prediction(uid='62', iid='7', r_ui=4.0, est=3.3301520923836874, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1019', r_ui=5.0, est=3.7550375589897156, details={'was_impossible': False}),
#  Prediction(uid='115', iid='177', r_ui=5.0, est=4.075249112449734, details={'was_impossible': False}),
#  Prediction(uid='561', iid='14', r_ui=3.0, est=3.5399675632344576, details={'was_impossible': False}),
#  Prediction(uid='757', iid='97', r_ui=4.0, est=3.5511109640799523, details={'was_impossible': False}),
#  Prediction(uid='641', iid='124', r_ui=4.0, est=4.243664041045849, details={'was_impossible': False}),
#  Prediction(uid='848', iid='739', r_ui=5.0, est=4.012954576191572, details={'was_impossible': False}),
#  Prediction(uid='585', iid='638', r_ui=4.0, est=3.8215589343184306, details={'was_impossible': False}),
#  Prediction(uid='401', iid='318', r_ui=4.0, est=3.9492581418523196, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1368', r_ui=5.0, est=2.876477163086537, details={'was_impossible': False}),
#  Prediction(uid='92', iid='452', r_ui=2.0, est=2.7680118573749906, details={'was_impossible': False}),
#  Prediction(uid='748', iid='732', r_ui=4.0, est=3.3214649284930777, details={'was_impossible': False}),
#  Prediction(uid='625', iid='50', r_ui=5.0, est=3.9995996138940337, details={'was_impossible': False}),
#  Prediction(uid='296', iid='181', r_ui=5.0, est=4.643510352844607, details={'was_impossible': False}),
#  Prediction(uid='601', iid='1296', r_ui=1.0, est=2.7339257470014195, details={'was_impossible': False}),
#  Prediction(uid='527', iid='628', r_ui=3.0, est=3.391930394324157, details={'was_impossible': False}),
#  Prediction(uid='145', iid='688', r_ui=4.0, est=1.9567185976613855, details={'was_impossible': False}),
#  Prediction(uid='698', iid='50', r_ui=5.0, est=3.780641118620223, details={'was_impossible': False}),
#  Prediction(uid='263', iid='153', r_ui=3.0, est=4.226052385561475, details={'was_impossible': False}),
#  Prediction(uid='151', iid='1197', r_ui=5.0, est=3.8664959376524095, details={'was_impossible': False}),
#  Prediction(uid='830', iid='100', r_ui=5.0, est=4.178702552233542, details={'was_impossible': False}),
#  Prediction(uid='927', iid='64', r_ui=5.0, est=4.661746589683675, details={'was_impossible': False}),
#  Prediction(uid='151', iid='609', r_ui=4.0, est=3.8311738342489083, details={'was_impossible': False}),
#  Prediction(uid='906', iid='628', r_ui=5.0, est=3.8091898624914378, details={'was_impossible': False}),
#  Prediction(uid='28', iid='436', r_ui=5.0, est=3.5831820354073463, details={'was_impossible': False}),
#  Prediction(uid='863', iid='300', r_ui=5.0, est=3.543708892043361, details={'was_impossible': False}),
#  Prediction(uid='805', iid='164', r_ui=3.0, est=3.1911886216700336, details={'was_impossible': False}),
#  Prediction(uid='359', iid='50', r_ui=5.0, est=4.547162799418908, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1222', r_ui=3.0, est=3.1425002514947513, details={'was_impossible': False}),
#  Prediction(uid='141', iid='1283', r_ui=3.0, est=3.0809677818781975, details={'was_impossible': False}),
#  Prediction(uid='34', iid='332', r_ui=5.0, est=4.136790764745848, details={'was_impossible': False}),
#  Prediction(uid='896', iid='572', r_ui=2.0, est=2.0488085336214135, details={'was_impossible': False}),
#  Prediction(uid='792', iid='844', r_ui=4.0, est=3.351736691157984, details={'was_impossible': False}),
#  Prediction(uid='612', iid='300', r_ui=4.0, est=3.5789652671108874, details={'was_impossible': False}),
#  Prediction(uid='703', iid='259', r_ui=1.0, est=2.8864508371291824, details={'was_impossible': False}),
#  Prediction(uid='293', iid='367', r_ui=2.0, est=2.996471156058654, details={'was_impossible': False}),
#  Prediction(uid='659', iid='837', r_ui=3.0, est=3.8028954964876998, details={'was_impossible': False}),
#  Prediction(uid='699', iid='683', r_ui=3.0, est=2.443442410413342, details={'was_impossible': False}),
#  Prediction(uid='64', iid='216', r_ui=4.0, est=3.78548630318298, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1405', r_ui=1.0, est=2.027564397396001, details={'was_impossible': False}),
#  Prediction(uid='152', iid='716', r_ui=5.0, est=3.909388695871286, details={'was_impossible': False}),
#  Prediction(uid='11', iid='191', r_ui=4.0, est=3.9439714409121684, details={'was_impossible': False}),
#  Prediction(uid='537', iid='543', r_ui=5.0, est=2.5770052831262777, details={'was_impossible': False}),
#  Prediction(uid='49', iid='238', r_ui=4.0, est=3.644188281452271, details={'was_impossible': False}),
#  Prediction(uid='495', iid='1263', r_ui=4.0, est=3.431863896273218, details={'was_impossible': False}),
#  Prediction(uid='533', iid='294', r_ui=4.0, est=2.9715800167729327, details={'was_impossible': False}),
#  Prediction(uid='868', iid='524', r_ui=3.0, est=3.3293742773690225, details={'was_impossible': False}),
#  Prediction(uid='840', iid='639', r_ui=4.0, est=4.071705185034988, details={'was_impossible': False}),
#  Prediction(uid='932', iid='163', r_ui=4.0, est=3.8161614016288357, details={'was_impossible': False}),
#  Prediction(uid='852', iid='681', r_ui=4.0, est=2.695635566339216, details={'was_impossible': False}),
#  Prediction(uid='505', iid='133', r_ui=5.0, est=3.180270495921165, details={'was_impossible': False}),
#  Prediction(uid='121', iid='405', r_ui=2.0, est=3.2769911108953806, details={'was_impossible': False}),
#  Prediction(uid='847', iid='104', r_ui=3.0, est=2.3598077177448964, details={'was_impossible': False}),
#  Prediction(uid='404', iid='750', r_ui=3.0, est=3.7878818343449905, details={'was_impossible': False}),
#  Prediction(uid='862', iid='179', r_ui=5.0, est=4.4446679582048425, details={'was_impossible': False}),
#  Prediction(uid='293', iid='176', r_ui=4.0, est=3.621235538457642, details={'was_impossible': False}),
#  Prediction(uid='25', iid='177', r_ui=3.0, est=4.158087832439536, details={'was_impossible': False}),
#  Prediction(uid='450', iid='715', r_ui=3.0, est=3.5261882407779765, details={'was_impossible': False}),
#  Prediction(uid='8', iid='689', r_ui=4.0, est=3.3282793617467705, details={'was_impossible': False}),
#  Prediction(uid='774', iid='182', r_ui=4.0, est=2.8765857526549046, details={'was_impossible': False}),
#  Prediction(uid='859', iid='111', r_ui=4.0, est=3.890605580665957, details={'was_impossible': False}),
#  Prediction(uid='804', iid='616', r_ui=3.0, est=3.6510585270674984, details={'was_impossible': False}),
#  Prediction(uid='130', iid='117', r_ui=5.0, est=4.673331788027652, details={'was_impossible': False}),
#  Prediction(uid='299', iid='508', r_ui=4.0, est=3.4429020907417827, details={'was_impossible': False}),
#  Prediction(uid='345', iid='676', r_ui=4.0, est=3.5163185805500317, details={'was_impossible': False}),
#  Prediction(uid='503', iid='134', r_ui=5.0, est=4.3189104984386235, details={'was_impossible': False}),
#  Prediction(uid='586', iid='181', r_ui=4.0, est=3.4626282162552897, details={'was_impossible': False}),
#  Prediction(uid='632', iid='550', r_ui=2.0, est=3.0895909973771047, details={'was_impossible': False}),
#  Prediction(uid='454', iid='250', r_ui=4.0, est=2.3939159363231783, details={'was_impossible': False}),
#  ...]

# %%
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9378
# 0.937753615643072

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7412
# 0.7411698412376106

# %%
from surprise.model_selection import cross_validate

cross_validate(model, df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9398  0.9287  0.9317  0.9423  0.9358  0.9357  0.0050
# MAE (testset)     0.7419  0.7315  0.7332  0.7448  0.7364  0.7376  0.0051
# Fit time          8.93    8.30    9.64    11.02   10.65   9.71    1.02
# Test time         0.26    0.42    0.33    0.49    0.35    0.37    0.08
# {'test_rmse': array([0.93981742, 0.92869945, 0.9316766 , 0.94231546, 0.93583622]),
#  'test_mae': array([0.74190938, 0.73149136, 0.73319539, 0.74484579, 0.73641292]),
#  'fit_time': (8.933404207229614,
#   8.2968430519104,
#   9.644875049591064,
#   11.021236896514893,
#   10.651102066040039),
#  'test_time': (0.2556474208831787,
#   0.4172201156616211,
#   0.33251500129699707,
#   0.48882555961608887,
#   0.34961986541748047)}

# %%
from surprise import KNNBasic
algo = KNNBasic()

# %%
bsl_options = {'method': 'als',
               'n_epochs': 20,
               }
sim_options = {'name': 'pearson_baseline'}

algo = KNNBasic(bsl_options=bsl_options, sim_options=sim_options)

# %%
print(model.fit(trainset))
# Out:
# <surprise.prediction_algorithms.matrix_factorization.SVD object at 0x0000020EF7EB8F40>

# %%
model.fit(trainset)

# %%
prediction1 = model.fit(trainset)

# %%
opts = {'name': 'pearson_baseline', 'user_based':True}

# %%
model3 = KNNBasic(sim_options=opts)

# %%
model3.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
predrection1 = model3.test(testset)

# %%
accuracy.rmse(predrection1)
# Out:
# RMSE: 1.0025
# 1.002521717490276

# %%
accuracy.mae(predrection1)
# Out:
# MAE:  0.7926
# 0.792613871311221

# %%
cross_validate(model3, df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0069  0.9990  1.0065  0.9918  0.9931  0.9995  0.0064
# MAE (testset)     0.7971  0.7893  0.7954  0.7865  0.7846  0.7906  0.0049
# Fit time          4.87    5.59    6.08    5.41    5.49    5.49    0.39
# Test time         7.49    8.51    7.25    9.01    8.15    8.08    0.65
# {'test_rmse': array([1.0069379 , 0.99904867, 1.00653297, 0.99175892, 0.99305495]),
#  'test_mae': array([0.79706951, 0.78934654, 0.79535278, 0.78651057, 0.78458793]),
#  'fit_time': (4.8699564933776855,
#   5.589486598968506,
#   6.077407360076904,
#   5.409131050109863,
#   5.488897085189819),
#  'test_time': (7.49415922164917,
#   8.511265993118286,
#   7.253827810287476,
#   9.012728214263916,
#   8.148248672485352)}

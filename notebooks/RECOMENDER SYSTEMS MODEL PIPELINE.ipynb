# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import KNNBaseline
from surprise.model_selection import GridSearchCV

# %%
from surprise.model_selection import train_test_split

# %%
df = Dataset.load_builtin('ml-100k')

# %%
trainset, testset = train_test_split(df, test_size=.25)

# %%
algo = SVD()

# %%
model = SVD()

# %%
testset
# Out:
# [('42', '427', 4.0),
#  ('425', '227', 4.0),
#  ('642', '1531', 3.0),
#  ('109', '4', 2.0),
#  ('125', '70', 3.0),
#  ('254', '98', 4.0),
#  ('276', '284', 4.0),
#  ('758', '191', 5.0),
#  ('479', '727', 5.0),
#  ('671', '455', 4.0),
#  ('146', '258', 4.0),
#  ('878', '269', 4.0),
#  ('407', '519', 4.0),
#  ('698', '479', 2.0),
#  ('207', '68', 2.0),
#  ('222', '157', 4.0),
#  ('426', '601', 3.0),
#  ('539', '285', 4.0),
#  ('868', '566', 1.0),
#  ('90', '287', 4.0),
#  ('491', '513', 5.0),
#  ('661', '216', 5.0),
#  ('694', '495', 4.0),
#  ('199', '259', 1.0),
#  ('186', '717', 3.0),
#  ('363', '25', 3.0),
#  ('868', '726', 2.0),
#  ('181', '880', 1.0),
#  ('184', '164', 3.0),
#  ('301', '631', 1.0),
#  ('568', '520', 2.0),
#  ('222', '106', 2.0),
#  ('342', '108', 4.0),
#  ('427', '359', 5.0),
#  ('784', '313', 5.0),
#  ('392', '179', 5.0),
#  ('293', '751', 3.0),
#  ('478', '143', 5.0),
#  ('346', '215', 3.0),
#  ('75', '137', 4.0),
#  ('217', '363', 1.0),
#  ('62', '59', 4.0),
# ...

# %%
trainset

# %%
algo.fit(trainset)
predictions = algo.test(testset)

# %%
from surprise import accuracy

# %%
predictions
# Out:
# [Prediction(uid='42', iid='427', r_ui=4.0, est=4.092754088905215, details={'was_impossible': False}),
#  Prediction(uid='425', iid='227', r_ui=4.0, est=2.692990511645963, details={'was_impossible': False}),
#  Prediction(uid='642', iid='1531', r_ui=3.0, est=3.804726284205014, details={'was_impossible': False}),
#  Prediction(uid='109', iid='4', r_ui=2.0, est=3.246782507158867, details={'was_impossible': False}),
#  Prediction(uid='125', iid='70', r_ui=3.0, est=3.477733469682515, details={'was_impossible': False}),
#  Prediction(uid='254', iid='98', r_ui=4.0, est=3.7796820351868323, details={'was_impossible': False}),
#  Prediction(uid='276', iid='284', r_ui=4.0, est=3.750567001565812, details={'was_impossible': False}),
#  Prediction(uid='758', iid='191', r_ui=5.0, est=4.50934817353998, details={'was_impossible': False}),
#  Prediction(uid='479', iid='727', r_ui=5.0, est=3.7313015010590065, details={'was_impossible': False}),
# ...

# %%
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9394
# 0.9394322369618526

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7406
# 0.7405708232171446

# %%
from surprise.model_selection import cross_validate

cross_validate(model, df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9419  0.9326  0.9423  0.9304  0.9369  0.9368  0.0048
# MAE (testset)     0.7441  0.7349  0.7409  0.7341  0.7389  0.7386  0.0037
# Fit time          8.28    7.92    7.81    7.48    7.27    7.75    0.35
# Test time         0.33    0.22    0.22    0.34    0.34    0.29    0.06
# {'test_rmse': array([0.94187944, 0.93261477, 0.94226781, 0.93044863, 0.93690857]),
#  'test_mae': array([0.74406155, 0.73488481, 0.7409442 , 0.73411333, 0.73888706]),
#  'fit_time': (8.28432011604309,
#   7.920512914657593,
#   7.8111817836761475,
#   7.477373361587524,
#   7.266251087188721),
#  'test_time': (0.3329148292541504,
#   0.21852493286132812,
#   0.21878957748413086,
#   0.3446693420410156,
#   0.335141658782959)}

# %%
from surprise import KNNBasic
algo = KNNBasic()

# %%
bsl_options = {'method': 'als',
               'n_epochs': 20,
               }
sim_options = {'name': 'pearson_baseline'}

algo = KNNBasic(bsl_options=bsl_options, sim_options=sim_options)

# %%
print(model.fit(trainset))

# %%
model.fit(trainset)

# %%
prediction1 = model.fit(trainset)

# %%
opts = {'name': 'pearson_baseline', 'user_based':True}

# %%
model3 = KNNBasic(sim_options=opts)

# %%
model3.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
prediction1 = model3.test(testset)

# %%
accuracy.rmse(prediction1)
# Out:
# RMSE: 0.6115
# 0.6114942063627802

# %%
accuracy.mae(prediction1)
# Out:
# MAE:  0.4456
# 0.44558836401647167

# %%
cross_validate(model3, df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9979  0.9948  1.0040  0.9918  1.0061  0.9989  0.0054
# MAE (testset)     0.7890  0.7858  0.7949  0.7859  0.7968  0.7905  0.0046
# Fit time          4.35    4.15    4.07    4.24    4.24    4.21    0.09
# ...

# %%
opts = {'name': 'Cosine', 'user_based':False}
model4 = KNNBasic(sim_options=opts)

# %%
model4.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
prediction4 = model4.test(testset)

# %%
accuracy.rmse(prediction4)
# Out:
# RMSE: 1.0239
# 1.0239225717602642

# %%
accuracy.mae(prediction4)
# Out:
# MAE:  0.8124
# 0.8124196290480007

# %%
x = accuracy.mae(prediction4)
# Out:
# MAE:  0.8124

# %%
cross_validate(model4, df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0318  1.0145  1.0291  1.0318  1.0234  1.0261  0.0066
# MAE (testset)     0.8131  0.8047  0.8127  0.8166  0.8095  0.8113  0.0040
# Fit time          5.51    5.24    5.32    5.36    5.11    5.31    0.13
# Test time         7.17    6.90    6.91    6.73    7.18    6.98    0.17
# {'test_rmse': array([1.03175026, 1.01447601, 1.02910001, 1.0317725 , 1.02344634]),
#  'test_mae': array([0.81306327, 0.8047077 , 0.81265719, 0.81658789, 0.80946424]),
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn 
import seaborn as sns
